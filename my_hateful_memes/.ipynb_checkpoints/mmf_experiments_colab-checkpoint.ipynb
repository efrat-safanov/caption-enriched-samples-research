# %% [markdown]
# # MMF Colab Demo
#
# This notebook provides step-by-step instructions on how to use MMF to build new models and uses the Hateful Memes (HM) dataset for this specific tutorial.
#
# Follow these links to learn more about MMF:
# - [MMF Blog Post]()
# - [GitHub repo](https://github.com/facebookresearch/mmf)
# - [Website](https://mmf.sh) and [Documentation](https://mmf.rtfd.io)
#
# In general, the notebook demonstrates how to:
#
# 1. [Download MMF](#scrollTo=l7Eo9ZqTDW3I)
# 2. [Download the HM dataset](#scrollTo=nYyXt9dzEBEU&line=12&uniqifier=1)
# 3. [Test pretrained models on HM](#scrollTo=nYyXt9dzEBEU&line=12&uniqifier=1)
# 4. [Submit a prediction](#scrollTo=uhKvYHtWHlyr&line=3&uniqifier=1)
# 5. [Train existing model on HM](#scrollTo=)
# 6. [Build your model](#scrollTo=)
# 7. [Train your model on HM](#scrollTo=)

# %% [markdown]
# ## Download MMF
#
# In this section, we will download the MMF package and required dependencies.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Prerequisites
# Please enable GPU in this notebook: Runtime > Change runtime type > Hardware Accelerator > Set to GPU

# %% [markdown]
# First we will install the MMF package and required dependencies

# %%
# !pip install git+https://github.com/facebookresearch/mmf.git
# Out:
# Collecting git+https://github.com/facebookresearch/mmf.git
#   Cloning https://github.com/facebookresearch/mmf.git to /tmp/pip-req-build-r0lt9ts9
#   Running command git clone -q https://github.com/facebookresearch/mmf.git /tmp/pip-req-build-r0lt9ts9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting torch==1.6.0
#   Downloading https://files.pythonhosted.org/packages/38/53/914885a93a44b96c0dd1c36f36ff10afe341f091230aad68f7228d61db1e/torch-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (748.8MB)
#      |████████████████████████████████| 748.8MB 22kB/s
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.6/dist-packages (from mmf==1.0.0rc12) (2.23.0)
# Collecting transformers==2.3.0
#   Downloading https://files.pythonhosted.org/packages/50/10/aeefced99c8a59d828a92cc11d213e2743212d3641c87c82d61b035a7d5c/transformers-2.3.0-py3-none-any.whl (447kB)
#      |████████████████████████████████| 450kB 60.5MB/s
# Collecting nltk==3.4.5
#   Downloading https://files.pythonhosted.org/packages/f6/1d/d925cfb4f324ede997f6d47bea4d9babba51b49e87a767c170b77005889d/nltk-3.4.5.zip (1.5MB)
#      |████████████████████████████████| 1.5MB 51.9MB/s
# Collecting fasttext==0.9.1
#   Downloading https://files.pythonhosted.org/packages/10/61/2e01f1397ec533756c1d893c22d9d5ed3fce3a6e4af1976e0d86bb13ea97/fasttext-0.9.1.tar.gz (57kB)
#      |████████████████████████████████| 61kB 8.6MB/s
# Collecting tqdm>=4.43.0
#   Downloading https://files.pythonhosted.org/packages/93/3a/96b3dc293aa72443cf9627444c3c221a7ba34bb622e4d8bf1b5d4f2d9d08/tqdm-4.51.0-py2.py3-none-any.whl (70kB)
#      |████████████████████████████████| 71kB 9.4MB/s
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.6/dist-packages (from mmf==1.0.0rc12) (1.1.0)
# Requirement already satisfied: editdistance==0.5.3 in /usr/local/lib/python3.6/dist-packages (from mmf==1.0.0rc12) (0.5.3)
# Requirement already satisfied: sklearn==0.0 in /usr/local/lib/python3.6/dist-packages (from mmf==1.0.0rc12) (0.0)
# Collecting torchtext==0.5.0
#   Downloading https://files.pythonhosted.org/packages/79/ef/54b8da26f37787f5c670ae2199329e7dccf195c060b25628d99e587dac51/torchtext-0.5.0-py3-none-any.whl (73kB)
#      |████████████████████████████████| 81kB 11.3MB/s
# Collecting lmdb==0.98
#   Downloading https://files.pythonhosted.org/packages/c0/5c/d56dbc2532ecf14fa004c543927500c0f645eaca8bd7ec39420c7546396a/lmdb-0.98.tar.gz (869kB)
#      |████████████████████████████████| 870kB 58.7MB/s
# Collecting demjson==2.2.4
#   Downloading https://files.pythonhosted.org/packages/96/67/6db789e2533158963d4af689f961b644ddd9200615b8ce92d6cad695c65a/demjson-2.2.4.tar.gz (131kB)
#      |████████████████████████████████| 133kB 58.3MB/s
# Collecting GitPython==3.1.0
#   Downloading https://files.pythonhosted.org/packages/d3/2f/6a366d56c9b1355b0880be9ea66b166cb3536392638d8d91413ec66305ad/GitPython-3.1.0-py3-none-any.whl (450kB)
#      |████████████████████████████████| 460kB 58.1MB/s
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.6/dist-packages (from mmf==1.0.0rc12) (1.18.5)
# Collecting torchvision==0.7.0
#   Downloading https://files.pythonhosted.org/packages/8e/dc/4a939cfbd38398f4765f712576df21425241020bfccc200af76d19088533/torchvision-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (5.9MB)
#      |████████████████████████████████| 5.9MB 13.5MB/s
# WARNING: The candidate selected for download or install is a yanked version: 'omegaconf' candidate (version 2.0.1rc4 at https://files.pythonhosted.org/packages/03/c6/dec84d1b2a3d645f03201dca03bc879b6116cb6503449a31d7ff9c1394a4/omegaconf-2.0.1rc4-py3-none-any.whl#sha256=e04462f7e3d8f51532221471b241f67e35a36a04e364c70987018faadd273cc0 (from https://pypi.org/simple/omegaconf/) (requires-python:>=3.6))
# Reason for being yanked: <none given>
# Collecting omegaconf==2.0.1rc4
#   Downloading https://files.pythonhosted.org/packages/03/c6/dec84d1b2a3d645f03201dca03bc879b6116cb6503449a31d7ff9c1394a4/omegaconf-2.0.1rc4-py3-none-any.whl
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0->mmf==1.0.0rc12) (0.16.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->mmf==1.0.0rc12) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->mmf==1.0.0rc12) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->mmf==1.0.0rc12) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->mmf==1.0.0rc12) (1.24.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==2.3.0->mmf==1.0.0rc12) (2019.12.20)
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/85/54/099a2ea5d4b2d5931a26f280a7585f613b1fafaac9189e489a9e25004a01/boto3-1.16.13-py2.py3-none-any.whl (129kB)
#      |████████████████████████████████| 133kB 64.8MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 61.6MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/e5/2d/6d4ca4bef9a67070fa1cac508606328329152b1df10bdf31fb6e4e727894/sentencepiece-0.1.94-cp36-cp36m-manylinux2014_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 59.8MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk==3.4.5->mmf==1.0.0rc12) (1.15.0)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.9.1->mmf==1.0.0rc12) (2.6.0)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.9.1->mmf==1.0.0rc12) (50.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn==0.0->mmf==1.0.0rc12) (0.22.2.post1)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 10.3MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.7.0->mmf==1.0.0rc12) (7.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from omegaconf==2.0.1rc4->mmf==1.0.0rc12) (3.7.4.3)
# Requirement already satisfied: dataclasses; python_version == "3.6" in /usr/local/lib/python3.6/dist-packages (from omegaconf==2.0.1rc4->mmf==1.0.0rc12) (0.7)
# Collecting PyYAML>=5.1.*
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 63.6MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting botocore<1.20.0,>=1.19.13
#   Downloading https://files.pythonhosted.org/packages/99/40/b5e681d80dc46bafd0dc2e55266190cc432dfd5b72b9e7e1c5743aa6c362/botocore-1.19.13-py2.py3-none-any.whl (6.7MB)
#      |████████████████████████████████| 6.7MB 64.3MB/s
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 9.8MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.3.0->mmf==1.0.0rc12) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.3.0->mmf==1.0.0rc12) (0.17.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn==0.0->mmf==1.0.0rc12) (1.4.1)
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.20.0,>=1.19.13->boto3->transformers==2.3.0->mmf==1.0.0rc12) (2.8.1)
# Building wheels for collected packages: mmf
#   Building wheel for mmf (PEP 517) ... done
#   Created wheel for mmf: filename=mmf-1.0.0rc12-cp36-cp36m-linux_x86_64.whl size=459524 sha256=798d16e8ffc2751ce83a5295774134aa06d1ae5242af5ff508edd65f05c43098
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6kjylxdt/wheels/25/8c/75/353b56ad9c6ff48146cd7bd3478f4d11f97b4d7a08cb153eb0
# Successfully built mmf
# Building wheels for collected packages: nltk, fasttext, lmdb, demjson, sacremoses, PyYAML
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449906 sha256=d8ec3a21af6b9f9fe1ba85e1c5e127e121351ffaa4114a20d706941379decac2
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.1-cp36-cp36m-linux_x86_64.whl size=2398466 sha256=f938acfbdbf5ffba0c0c5c0d13f296d4a5c252928fe2a79efae4401e602dcf77
#   Stored in directory: /root/.cache/pip/wheels/9f/f0/04/caa82c912aee89ce76358ff954f3f0729b7577c8ff23a292e3
#   Building wheel for lmdb (setup.py) ... done
#   Created wheel for lmdb: filename=lmdb-0.98-cp36-cp36m-linux_x86_64.whl size=218601 sha256=ec7106d3b4a4b7f5a0608a2540e52c02439085eeb5bfc79410076d57f2bca245
#   Stored in directory: /root/.cache/pip/wheels/a1/97/8c/7721e4b6b0ac723c6cc45ecca60599a80f75e2367330647390
#   Building wheel for demjson (setup.py) ... done
#   Created wheel for demjson: filename=demjson-2.2.4-cp36-none-any.whl size=73547 sha256=052f3a85e7a09c466d2c7f6c0ceb6f87f1049a7bea5da7c85b9ca292f92fca09
#   Stored in directory: /root/.cache/pip/wheels/c5/d2/ab/a54fb5ea53ac3badba098160e8452fa126a51febda80440ded
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=1113213117a37000cb2f69025f149c767d32731d853a066f3ca008a33a72741d
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=0c464c5c3298bae22f2b66829f6d038182fa229ee5a13e17bfe540e36552f0b2
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built nltk fasttext lmdb demjson sacremoses PyYAML
# ERROR: botocore 1.19.13 has requirement urllib3<1.26,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# Installing collected packages: torch, tqdm, jmespath, botocore, s3transfer, boto3, sacremoses, sentencepiece, transformers, nltk, fasttext, torchtext, lmdb, demjson, smmap, gitdb, GitPython, torchvision, PyYAML, omegaconf, mmf
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
#       Successfully uninstalled torchtext-0.3.1
#   Found existing installation: lmdb 0.99
#     Uninstalling lmdb-0.99:
#       Successfully uninstalled lmdb-0.99
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed GitPython-3.1.0 PyYAML-5.3.1 boto3-1.16.13 botocore-1.19.13 demjson-2.2.4 fasttext-0.9.1 gitdb-4.0.5 jmespath-0.10.0 lmdb-0.98 mmf-1.0.0rc12 nltk-3.4.5 omegaconf-2.0.1rc4 s3transfer-0.3.3 sacremoses-0.0.43 sentencepiece-0.1.94 smmap-3.0.4 torch-1.6.0 torchtext-0.5.0 torchvision-0.7.0 tqdm-4.51.0 transformers-2.3.0

# %% [markdown]
# ## Download dataset
#
# We will now download the Hateful Memes dataset. You will require two things to download the datasets: (i) URL (ii) Password to the zip file. To get both of these follow these steps:
#
# 1. Go to [DrivenData challenge page](https://www.drivendata.org/competitions/64/hateful-memes/)
# 2. Register, read and acknowledge the agreements for data access.
# 3. Go to the [data page](https://www.drivendata.org/competitions/64/hateful-memes/data), right click on the "Hateful Memes challenge dataset" link and "Copy Link Address" as shown in the image. This will copy the URL for the zip file to your clipboard which you will use in the next step.
# ![data](https://i.imgur.com/JQx2hPm.png)
# 4. Also, note the password provided in the description.
# 5. Run the next code block, fill in the URL and the zipfile's password when prompted.
#
# The code blocks after that will download, convert and visualize the dataset.

# %%
from getpass import getpass, getuser
url = "https://drivendata-competition-fb-hateful-memes-data.s3.amazonaws.com/XjiOc5ycDBRRNwbhRlgH.zip?AWSAccessKeyId=AKIARVBOBDCY4MWEDJKS&Signature=nxpEae48jyVyguPq%2BcUVnqM1IB8%3D&Expires=1604106079" #getpass("Enter the Hateful Memes data URL:")
password = "EWryfbZyNviilcDF" #getpass("Enter ZIP file's Password:")

# %% [markdown]
# This will actually download the data.

# %%
 #pip install awscli awsebcli botocore==1.18.18 --upgrade

# %%
#!curl -o /content/hm.zip "$url" -H 'Referer: https://www.drivendata.org/competitions/64/hateful-memes/data/' --compressed

# %% [markdown]
# The next command will convert the zip file into required MMF format.

# %%
# !rm -rf /root/.cache/torch/mmf/data/datasets/hateful_memes
# !mmf_convert_hm --zip_file "/content/drive/My Drive/msc computer science/deep learning/DL course/hm.zip" --password $password --bypass_checksum=1
# Out:
# 2020-11-08 09:43:26.146229: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# Data folder is /root/.cache/torch/mmf/data
# Zip path is /content/drive/My Drive/msc computer science/deep learning/DL course/hm.zip
# Copying /content/drive/My Drive/msc computer science/deep learning/DL course/hm.zip
# Unzipping /content/drive/My Drive/msc computer science/deep learning/DL course/hm.zip
# Extracting the zip can take time. Sit back and relax.
# Moving train.jsonl
# Moving dev_seen.jsonl
# Moving test_seen.jsonl
# Moving dev_unseen.jsonl
# Moving test_unseen.jsonl
# Moving img

# %% [markdown]
# ### Visualize
#
# The next code block will output some samples of the dataset for visualization. You can adjust number of samples, rows and size among other stuff.
#
# **Note:** *Some of the images in the hateful memes dataset are sensitive and may not be suitable for all audiences. Please run the next code responsibly keeping these conditions in mind.*

# %%
from mmf.common.registry import registry
from mmf.models.mmbt import MMBT
from mmf.utils.build import build_dataset

from mmf.utils.env import setup_imports
setup_imports()
dataset = build_dataset("hateful_memes")

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20, 20)
dataset.visualize(num_samples=8, size=(512, 512), nrow=4)
# Out:
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# Downloading extras.tar.gz: 0.00B [00:00, ?B/s]
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/datasets/hateful_memes/defaults/extras.tar.gz to /root/.cache/torch/mmf/data/datasets/hateful_memes/defaults/extras.tar.gz ]
# Downloading extras.tar.gz: 100%|██████████| 211k/211k [00:00<00:00, 309kB/s]
# /root/.cache/torch/mmf/glove.6B.zip: 0.00B [00:00, ?B/s]
# [ Starting checksum for extras.tar.gz]
# [ Checksum successful for extras.tar.gz]
# Unpacking extras.tar.gz
# /root/.cache/torch/mmf/glove.6B.zip: 862MB [06:29, 2.21MB/s]
# 100%|█████████▉| 399999/400000 [00:42<00:00, 9459.44it/s]

# %% [markdown]
# ## Test pretrained model
#
# We will now use MMF to load an existing model MMBT to run some tests on random images from the internet. Fill in the image url and the text contained in it to see if the model thinks of it as hateful or not.

# %%
import matplotlib.pyplot as plt
import requests

from PIL import Image

from mmf.models.mmbt import MMBT
#from mmf.models.vilbert import ViLBERT


model = MMBT.from_pretrained("mmbt.hateful_memes.images")
#model = ViLBERT.from_pretrained("vilbert.finetuned.hateful_memes.direct")
# Out:
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# Downloading mmbt.finetuned.hateful_memes_images.tar.gz: 0.00B [00:00, ?B/s]
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/mmbt/mmbt.finetuned.hateful_memes_images_2020_08_20.tar.gz to /root/.cache/torch/mmf/data/models/mmbt.hateful_memes.images/mmbt.finetuned.hateful_memes_images.tar.gz ]
# Downloading mmbt.finetuned.hateful_memes_images.tar.gz: 100%|██████████| 630M/630M [00:22<00:00, 27.8MB/s]
# [ Starting checksum for mmbt.finetuned.hateful_memes_images.tar.gz]
# [ Checksum successful for mmbt.finetuned.hateful_memes_images.tar.gz]
# Unpacking mmbt.finetuned.hateful_memes_images.tar.gz

# %%
#image_url = "https://drivendata-prod-public.s3.amazonaws.com/comp_images/sample_meme_skunk.png" #@param {type:"string"}
#text = "love the way you smell today" #@param {type: "string"}
image_url = "https://i.imgur.com/tEcsk5q.jpg" #@param {type:"string"}
text = "look how many people love you" #@param {type: "string"}

print(text)
output = model.classify(image_url, text)
print(output)
plt.imshow(Image.open(requests.get(image_url, stream=True).raw))
plt.axis("off")
plt.show()
hateful = "Yes" if output["label"] == 1 else "No"
print("Hateful as per the model (should be - no)?", hateful)
print(f"Model's confidence: {output['confidence'] * 100:.3f}%")

text = "Hitler and jews"
print(text)
output = model.classify(image_url, "Hitler and jews")
print(output)
plt.imshow(Image.open(requests.get(image_url, stream=True).raw))
plt.axis("off")
plt.show()
hateful = "Yes" if output["label"] == 1 else "No"
print("Hateful as per the model (should be - yes)? ", hateful)
print(f"Model's confidence: {output['confidence'] * 100:.3f}%")
# Out:
# look how many people love you
# {'label': 0, 'confidence': 0.999462902545929}
# Hateful as per the model (should be - no)? No
# Model's confidence: 99.946%
# Hitler and jews
# {'label': 1, 'confidence': 0.8346763849258423}
# Hateful as per the model (should be - yes)?  Yes
# Model's confidence: 83.468%

# %% [markdown]
# ## Submit a prediction
#
# Now, we will use a pretrained model from MMF to submit a prediction to DrivenData. Run the command in the next block and at the end it will output the path to the csv file generated. Download and upload that file to [DrivenData's submission page](https://www.drivendata.org/competitions/64/hateful-memes/submissions/).

# %%
#mmbt-grid - validate

# !mmf_predict config=projects/hateful_memes/configs/mmbt/defaults.yaml model=mmbt dataset=hateful_memes run_type=val checkpoint.resume_zoo=mmbt.hateful_memes.images training.batch_size=16 dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-11-08 07:01:52.712301: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/mmbt/defaults.yaml
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option model to mmbt
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option run_type to val
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option checkpoint.resume_zoo to mmbt.hateful_memes.images
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option training.batch_size to 16
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-11-08T07:01:57 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-11-08T07:01:57 | mmf: Logging to: ./save/train.log
# 2020-11-08T07:01:57 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/mmbt/defaults.yaml', 'model=mmbt', 'dataset=hateful_memes', 'run_type=val', 'checkpoint.resume_zoo=mmbt.hateful_memes.images', 'training.batch_size=16', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-11-08T07:01:57 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-08T07:01:57 | mmf_cli.run: Using seed 57168798
# 2020-11-08T07:01:57 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-11-08T07:01:58 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-08T07:02:01 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-08T07:02:01 | transformers.file_utils: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpieexn2wa
# 2020-11-08T07:02:01 | transformers.file_utils: copying /tmp/tmpieexn2wa to cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2020-11-08T07:02:01 | transformers.file_utils: creating metadata file for /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2020-11-08T07:02:01 | transformers.file_utils: removing temp file /tmp/tmpieexn2wa
# 2020-11-08T07:02:01 | transformers.configuration_utils: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2020-11-08T07:02:01 | transformers.configuration_utils: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 2020-11-08T07:02:02 | transformers.file_utils: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin not found in cache or force_download set to True, downloading to /tmp/tmpio42ifec
# 2020-11-08T07:02:19 | transformers.file_utils: copying /tmp/tmpio42ifec to cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-08T07:02:20 | transformers.file_utils: creating metadata file for /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-08T07:02:20 | transformers.file_utils: removing temp file /tmp/tmpio42ifec
# 2020-11-08T07:02:20 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /root/.cache/torch/hub/checkpoints/resnet152-b121ed2d.pth
# 100% 230M/230M [00:02<00:00, 87.3MB/s]
# 2020-11-08T07:02:30 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-08T07:02:30 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-08T07:02:30 | mmf.utils.checkpoint: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/mmbt/mmbt.finetuned.hateful_memes_images_2020_08_20.tar.gz to /root/.cache/torch/mmf/data/models/mmbt.hateful_memes.images/mmbt.finetuned.hateful_memes_images.tar.gz ]
# Downloading mmbt.finetuned.hateful_memes_images.tar.gz: 100% 630M/630M [00:56<00:00, 11.1MB/s]
# [ Starting checksum for mmbt.finetuned.hateful_memes_images.tar.gz]
# [ Checksum successful for mmbt.finetuned.hateful_memes_images.tar.gz]
# Unpacking mmbt.finetuned.hateful_memes_images.tar.gz
# WARNING 2020-11-08T07:03:37 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-08T07:03:37 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-08T07:03:37 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-08T07:03:37 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-08T07:03:38 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-08T07:03:38 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-08T07:03:38 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# WARNING 2020-11-08T07:03:38 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# 2020-11-08T07:03:38 | mmf.utils.checkpoint: Checkpoint loaded.
# 2020-11-08T07:03:38 | mmf.utils.checkpoint: Current num updates: 0
# 2020-11-08T07:03:38 | mmf.utils.checkpoint: Current iteration: 0
# 2020-11-08T07:03:38 | mmf.utils.checkpoint: Current epoch: 0
# 2020-11-08T07:03:38 | mmf.trainers.core.evaluation_loop: Starting val inference predictions
# 2020-11-08T07:03:38 | mmf.common.test_reporter: Predicting for hateful_memes
# 100% 32/32 [02:49<00:00,  5.30s/it]
# 2020-11-08T07:06:27 | mmf.common.test_reporter: Wrote predictions for hateful_memes to /content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_val_2020-11-08T07:06:27.csv
# 2020-11-08T07:06:27 | mmf.trainers.core.evaluation_loop: Finished predicting

# %%
#mmbt-grid
#!mmf_predict config=projects/hateful_memes/configs/mmbt/defaults.yaml model=mmbt dataset=hateful_memes run_type=test checkpoint.resume_zoo=mmbt.hateful_memes.images training.batch_size=16 dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
#dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"

#vilbert
# !mmf_predict config=projects/hateful_memes/configs/vilbert/defaults.yaml model=vilbert dataset=hateful_memes run_type=test checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.from_cc_original dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-11-05 10:36:09.567038: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# 2020-11-05T10:36:11 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/vilbert/defaults.yaml
# 2020-11-05T10:36:11 | mmf.utils.configuration: Overriding option model to vilbert
# 2020-11-05T10:36:11 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-05T10:36:11 | mmf.utils.configuration: Overriding option run_type to test
# 2020-11-05T10:36:11 | mmf.utils.configuration: Overriding option checkpoint.resume_zoo to vilbert.finetuned.hateful_memes.from_cc_original
# 2020-11-05T10:36:11 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-11-05T10:36:11 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-11-05T10:36:11 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-11-05T10:36:11 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-11-05T10:36:11 | mmf: Logging to: ./save/train.log
# 2020-11-05T10:36:11 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/vilbert/defaults.yaml', 'model=vilbert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.from_cc_original', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-11-05T10:36:11 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-05T10:36:11 | mmf_cli.run: Using seed 11985143
# 2020-11-05T10:36:11 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-11-05T10:36:13 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-05T10:36:15 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-05T10:36:16 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-05T10:36:20 | transformers.modeling_utils: Weights of ViLBERTBase not initialized from pretrained model: ['bert.v_embeddings.image_embeddings.weight', 'bert.v_embeddings.image_embeddings.bias', 'bert.v_embeddings.image_location_embeddings.weight', 'bert.v_embeddings.image_location_embeddings.bias', 'bert.v_embeddings.LayerNorm.weight', 'bert.v_embeddings.LayerNorm.bias', 'bert.encoder.v_layer.0.attention.self.query.weight', 'bert.encoder.v_layer.0.attention.self.query.bias', 'bert.encoder.v_layer.0.attention.self.key.weight', 'bert.encoder.v_layer.0.attention.self.key.bias', 'bert.encoder.v_layer.0.attention.self.value.weight', 'bert.encoder.v_layer.0.attention.self.value.bias', 'bert.encoder.v_layer.0.attention.output.dense.weight', 'bert.encoder.v_layer.0.attention.output.dense.bias', 'bert.encoder.v_layer.0.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.0.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.0.intermediate.dense.weight', 'bert.encoder.v_layer.0.intermediate.dense.bias', 'bert.encoder.v_layer.0.output.dense.weight', 'bert.encoder.v_layer.0.output.dense.bias', 'bert.encoder.v_layer.0.output.LayerNorm.weight', 'bert.encoder.v_layer.0.output.LayerNorm.bias', 'bert.encoder.v_layer.1.attention.self.query.weight', 'bert.encoder.v_layer.1.attention.self.query.bias', 'bert.encoder.v_layer.1.attention.self.key.weight', 'bert.encoder.v_layer.1.attention.self.key.bias', 'bert.encoder.v_layer.1.attention.self.value.weight', 'bert.encoder.v_layer.1.attention.self.value.bias', 'bert.encoder.v_layer.1.attention.output.dense.weight', 'bert.encoder.v_layer.1.attention.output.dense.bias', 'bert.encoder.v_layer.1.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.1.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.1.intermediate.dense.weight', 'bert.encoder.v_layer.1.intermediate.dense.bias', 'bert.encoder.v_layer.1.output.dense.weight', 'bert.encoder.v_layer.1.output.dense.bias', 'bert.encoder.v_layer.1.output.LayerNorm.weight', 'bert.encoder.v_layer.1.output.LayerNorm.bias', 'bert.encoder.v_layer.2.attention.self.query.weight', 'bert.encoder.v_layer.2.attention.self.query.bias', 'bert.encoder.v_layer.2.attention.self.key.weight', 'bert.encoder.v_layer.2.attention.self.key.bias', 'bert.encoder.v_layer.2.attention.self.value.weight', 'bert.encoder.v_layer.2.attention.self.value.bias', 'bert.encoder.v_layer.2.attention.output.dense.weight', 'bert.encoder.v_layer.2.attention.output.dense.bias', 'bert.encoder.v_layer.2.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.2.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.2.intermediate.dense.weight', 'bert.encoder.v_layer.2.intermediate.dense.bias', 'bert.encoder.v_layer.2.output.dense.weight', 'bert.encoder.v_layer.2.output.dense.bias', 'bert.encoder.v_layer.2.output.LayerNorm.weight', 'bert.encoder.v_layer.2.output.LayerNorm.bias', 'bert.encoder.v_layer.3.attention.self.query.weight', 'bert.encoder.v_layer.3.attention.self.query.bias', 'bert.encoder.v_layer.3.attention.self.key.weight', 'bert.encoder.v_layer.3.attention.self.key.bias', 'bert.encoder.v_layer.3.attention.self.value.weight', 'bert.encoder.v_layer.3.attention.self.value.bias', 'bert.encoder.v_layer.3.attention.output.dense.weight', 'bert.encoder.v_layer.3.attention.output.dense.bias', 'bert.encoder.v_layer.3.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.3.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.3.intermediate.dense.weight', 'bert.encoder.v_layer.3.intermediate.dense.bias', 'bert.encoder.v_layer.3.output.dense.weight', 'bert.encoder.v_layer.3.output.dense.bias', 'bert.encoder.v_layer.3.output.LayerNorm.weight', 'bert.encoder.v_layer.3.output.LayerNorm.bias', 'bert.encoder.v_layer.4.attention.self.query.weight', 'bert.encoder.v_layer.4.attention.self.query.bias', 'bert.encoder.v_layer.4.attention.self.key.weight', 'bert.encoder.v_layer.4.attention.self.key.bias', 'bert.encoder.v_layer.4.attention.self.value.weight', 'bert.encoder.v_layer.4.atte ...
# 2020-11-05T10:36:20 | transformers.modeling_utils: Weights from pretrained model not used in ViLBERTBase: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# 2020-11-05T10:36:20 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-05T10:36:20 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-05T10:36:20 | mmf.utils.checkpoint: Loading checkpoint
# WARNING 2020-11-05T10:36:21 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-05T10:36:21 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-05T10:36:21 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-05T10:36:21 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-05T10:36:22 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-05T10:36:22 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-05T10:36:22 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# WARNING 2020-11-05T10:36:22 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# 2020-11-05T10:36:22 | mmf.utils.checkpoint: Checkpoint loaded.
# 2020-11-05T10:36:22 | mmf.utils.checkpoint: Current num updates: 0
# 2020-11-05T10:36:22 | mmf.utils.checkpoint: Current iteration: 0
# 2020-11-05T10:36:22 | mmf.utils.checkpoint: Current epoch: 0
# 2020-11-05T10:36:22 | mmf.trainers.core.evaluation_loop: Starting test inference predictions
# 2020-11-05T10:36:22 | mmf.common.test_reporter: Predicting for hateful_memes
# 100% 32/32 [04:39<00:00,  8.74s/it]
# 2020-11-05T10:41:02 | mmf.common.test_reporter: Wrote predictions for hateful_memes to /content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_test_2020-11-05T10:41:02.csv
# 2020-11-05T10:41:02 | mmf.trainers.core.evaluation_loop: Finished predicting

# %%
#vilbert validate files - multimodal
# !mmf_predict config=projects/hateful_memes/configs/vilbert/defaults.yaml model=vilbert dataset=hateful_memes run_type=val checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.from_cc_original dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-11-06 07:59:47.378058: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# 2020-11-06T07:59:51 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/vilbert/defaults.yaml
# 2020-11-06T07:59:51 | mmf.utils.configuration: Overriding option model to vilbert
# 2020-11-06T07:59:51 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-06T07:59:51 | mmf.utils.configuration: Overriding option run_type to val
# 2020-11-06T07:59:51 | mmf.utils.configuration: Overriding option checkpoint.resume_zoo to vilbert.finetuned.hateful_memes.from_cc_original
# 2020-11-06T07:59:51 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-11-06T07:59:51 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-11-06T07:59:51 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-11-06T07:59:51 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-11-06T07:59:51 | mmf: Logging to: ./save/train.log
# 2020-11-06T07:59:51 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/vilbert/defaults.yaml', 'model=vilbert', 'dataset=hateful_memes', 'run_type=val', 'checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.from_cc_original', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-11-06T07:59:51 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-06T07:59:51 | mmf_cli.run: Using seed 51503289
# 2020-11-06T07:59:51 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-11-06T07:59:52 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-06T07:59:55 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-06T07:59:55 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-06T07:59:59 | transformers.modeling_utils: Weights of ViLBERTBase not initialized from pretrained model: ['bert.v_embeddings.image_embeddings.weight', 'bert.v_embeddings.image_embeddings.bias', 'bert.v_embeddings.image_location_embeddings.weight', 'bert.v_embeddings.image_location_embeddings.bias', 'bert.v_embeddings.LayerNorm.weight', 'bert.v_embeddings.LayerNorm.bias', 'bert.encoder.v_layer.0.attention.self.query.weight', 'bert.encoder.v_layer.0.attention.self.query.bias', 'bert.encoder.v_layer.0.attention.self.key.weight', 'bert.encoder.v_layer.0.attention.self.key.bias', 'bert.encoder.v_layer.0.attention.self.value.weight', 'bert.encoder.v_layer.0.attention.self.value.bias', 'bert.encoder.v_layer.0.attention.output.dense.weight', 'bert.encoder.v_layer.0.attention.output.dense.bias', 'bert.encoder.v_layer.0.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.0.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.0.intermediate.dense.weight', 'bert.encoder.v_layer.0.intermediate.dense.bias', 'bert.encoder.v_layer.0.output.dense.weight', 'bert.encoder.v_layer.0.output.dense.bias', 'bert.encoder.v_layer.0.output.LayerNorm.weight', 'bert.encoder.v_layer.0.output.LayerNorm.bias', 'bert.encoder.v_layer.1.attention.self.query.weight', 'bert.encoder.v_layer.1.attention.self.query.bias', 'bert.encoder.v_layer.1.attention.self.key.weight', 'bert.encoder.v_layer.1.attention.self.key.bias', 'bert.encoder.v_layer.1.attention.self.value.weight', 'bert.encoder.v_layer.1.attention.self.value.bias', 'bert.encoder.v_layer.1.attention.output.dense.weight', 'bert.encoder.v_layer.1.attention.output.dense.bias', 'bert.encoder.v_layer.1.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.1.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.1.intermediate.dense.weight', 'bert.encoder.v_layer.1.intermediate.dense.bias', 'bert.encoder.v_layer.1.output.dense.weight', 'bert.encoder.v_layer.1.output.dense.bias', 'bert.encoder.v_layer.1.output.LayerNorm.weight', 'bert.encoder.v_layer.1.output.LayerNorm.bias', 'bert.encoder.v_layer.2.attention.self.query.weight', 'bert.encoder.v_layer.2.attention.self.query.bias', 'bert.encoder.v_layer.2.attention.self.key.weight', 'bert.encoder.v_layer.2.attention.self.key.bias', 'bert.encoder.v_layer.2.attention.self.value.weight', 'bert.encoder.v_layer.2.attention.self.value.bias', 'bert.encoder.v_layer.2.attention.output.dense.weight', 'bert.encoder.v_layer.2.attention.output.dense.bias', 'bert.encoder.v_layer.2.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.2.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.2.intermediate.dense.weight', 'bert.encoder.v_layer.2.intermediate.dense.bias', 'bert.encoder.v_layer.2.output.dense.weight', 'bert.encoder.v_layer.2.output.dense.bias', 'bert.encoder.v_layer.2.output.LayerNorm.weight', 'bert.encoder.v_layer.2.output.LayerNorm.bias', 'bert.encoder.v_layer.3.attention.self.query.weight', 'bert.encoder.v_layer.3.attention.self.query.bias', 'bert.encoder.v_layer.3.attention.self.key.weight', 'bert.encoder.v_layer.3.attention.self.key.bias', 'bert.encoder.v_layer.3.attention.self.value.weight', 'bert.encoder.v_layer.3.attention.self.value.bias', 'bert.encoder.v_layer.3.attention.output.dense.weight', 'bert.encoder.v_layer.3.attention.output.dense.bias', 'bert.encoder.v_layer.3.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.3.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.3.intermediate.dense.weight', 'bert.encoder.v_layer.3.intermediate.dense.bias', 'bert.encoder.v_layer.3.output.dense.weight', 'bert.encoder.v_layer.3.output.dense.bias', 'bert.encoder.v_layer.3.output.LayerNorm.weight', 'bert.encoder.v_layer.3.output.LayerNorm.bias', 'bert.encoder.v_layer.4.attention.self.query.weight', 'bert.encoder.v_layer.4.attention.self.query.bias', 'bert.encoder.v_layer.4.attention.self.key.weight', 'bert.encoder.v_layer.4.attention.self.key.bias', 'bert.encoder.v_layer.4.attention.self.value.weight', 'bert.encoder.v_layer.4.atte ...
# 2020-11-06T07:59:59 | transformers.modeling_utils: Weights from pretrained model not used in ViLBERTBase: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# 2020-11-06T07:59:59 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-06T07:59:59 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-06T07:59:59 | mmf.utils.checkpoint: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/vilbert/vilbert.finetuned.hateful_memes_from_cc.tar.gz to /root/.cache/torch/mmf/data/models/vilbert.finetuned.hateful_memes.from_cc_original/vilbert.finetuned.hateful_memes_from_cc.tar.gz ]
# Downloading vilbert.finetuned.hateful_memes_from_cc.tar.gz: 100% 918M/918M [00:14<00:00, 63.1MB/s]
# [ Starting checksum for vilbert.finetuned.hateful_memes_from_cc.tar.gz]
# [ Checksum successful for vilbert.finetuned.hateful_memes_from_cc.tar.gz]
# Unpacking vilbert.finetuned.hateful_memes_from_cc.tar.gz
# WARNING 2020-11-06T08:00:26 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:00:26 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:00:26 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:00:26 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:00:27 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:00:27 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:00:27 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# WARNING 2020-11-06T08:00:27 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# 2020-11-06T08:00:27 | mmf.utils.checkpoint: Checkpoint loaded.
# 2020-11-06T08:00:27 | mmf.utils.checkpoint: Current num updates: 0
# 2020-11-06T08:00:27 | mmf.utils.checkpoint: Current iteration: 0
# 2020-11-06T08:00:27 | mmf.utils.checkpoint: Current epoch: 0
# 2020-11-06T08:00:27 | mmf.trainers.core.evaluation_loop: Starting val inference predictions
# 2020-11-06T08:00:27 | mmf.common.test_reporter: Predicting for hateful_memes
# 100% 16/16 [03:36<00:00, 13.54s/it]
# 2020-11-06T08:04:04 | mmf.common.test_reporter: Wrote predictions for hateful_memes to /content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_val_2020-11-06T08:04:04.csv
# 2020-11-06T08:04:04 | mmf.trainers.core.evaluation_loop: Finished predicting

# %%
#vilbert validate - unimodal
# !mmf_predict config=projects/hateful_memes/configs/vilbert/defaults.yaml model=vilbert dataset=hateful_memes run_type=val checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.direct dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-11-06 08:24:39.523586: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# 2020-11-06T08:24:41 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/vilbert/defaults.yaml
# 2020-11-06T08:24:41 | mmf.utils.configuration: Overriding option model to vilbert
# 2020-11-06T08:24:41 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-06T08:24:41 | mmf.utils.configuration: Overriding option run_type to val
# 2020-11-06T08:24:41 | mmf.utils.configuration: Overriding option checkpoint.resume_zoo to vilbert.finetuned.hateful_memes.direct
# 2020-11-06T08:24:41 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-11-06T08:24:41 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-11-06T08:24:41 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-11-06T08:24:41 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-11-06T08:24:42 | mmf: Logging to: ./save/train.log
# 2020-11-06T08:24:42 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/vilbert/defaults.yaml', 'model=vilbert', 'dataset=hateful_memes', 'run_type=val', 'checkpoint.resume_zoo=vilbert.finetuned.hateful_memes.direct', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-11-06T08:24:42 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-06T08:24:42 | mmf_cli.run: Using seed 42026741
# 2020-11-06T08:24:42 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-11-06T08:24:43 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-06T08:24:46 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-06T08:24:46 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-06T08:24:50 | transformers.modeling_utils: Weights of ViLBERTBase not initialized from pretrained model: ['bert.v_embeddings.image_embeddings.weight', 'bert.v_embeddings.image_embeddings.bias', 'bert.v_embeddings.image_location_embeddings.weight', 'bert.v_embeddings.image_location_embeddings.bias', 'bert.v_embeddings.LayerNorm.weight', 'bert.v_embeddings.LayerNorm.bias', 'bert.encoder.v_layer.0.attention.self.query.weight', 'bert.encoder.v_layer.0.attention.self.query.bias', 'bert.encoder.v_layer.0.attention.self.key.weight', 'bert.encoder.v_layer.0.attention.self.key.bias', 'bert.encoder.v_layer.0.attention.self.value.weight', 'bert.encoder.v_layer.0.attention.self.value.bias', 'bert.encoder.v_layer.0.attention.output.dense.weight', 'bert.encoder.v_layer.0.attention.output.dense.bias', 'bert.encoder.v_layer.0.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.0.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.0.intermediate.dense.weight', 'bert.encoder.v_layer.0.intermediate.dense.bias', 'bert.encoder.v_layer.0.output.dense.weight', 'bert.encoder.v_layer.0.output.dense.bias', 'bert.encoder.v_layer.0.output.LayerNorm.weight', 'bert.encoder.v_layer.0.output.LayerNorm.bias', 'bert.encoder.v_layer.1.attention.self.query.weight', 'bert.encoder.v_layer.1.attention.self.query.bias', 'bert.encoder.v_layer.1.attention.self.key.weight', 'bert.encoder.v_layer.1.attention.self.key.bias', 'bert.encoder.v_layer.1.attention.self.value.weight', 'bert.encoder.v_layer.1.attention.self.value.bias', 'bert.encoder.v_layer.1.attention.output.dense.weight', 'bert.encoder.v_layer.1.attention.output.dense.bias', 'bert.encoder.v_layer.1.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.1.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.1.intermediate.dense.weight', 'bert.encoder.v_layer.1.intermediate.dense.bias', 'bert.encoder.v_layer.1.output.dense.weight', 'bert.encoder.v_layer.1.output.dense.bias', 'bert.encoder.v_layer.1.output.LayerNorm.weight', 'bert.encoder.v_layer.1.output.LayerNorm.bias', 'bert.encoder.v_layer.2.attention.self.query.weight', 'bert.encoder.v_layer.2.attention.self.query.bias', 'bert.encoder.v_layer.2.attention.self.key.weight', 'bert.encoder.v_layer.2.attention.self.key.bias', 'bert.encoder.v_layer.2.attention.self.value.weight', 'bert.encoder.v_layer.2.attention.self.value.bias', 'bert.encoder.v_layer.2.attention.output.dense.weight', 'bert.encoder.v_layer.2.attention.output.dense.bias', 'bert.encoder.v_layer.2.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.2.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.2.intermediate.dense.weight', 'bert.encoder.v_layer.2.intermediate.dense.bias', 'bert.encoder.v_layer.2.output.dense.weight', 'bert.encoder.v_layer.2.output.dense.bias', 'bert.encoder.v_layer.2.output.LayerNorm.weight', 'bert.encoder.v_layer.2.output.LayerNorm.bias', 'bert.encoder.v_layer.3.attention.self.query.weight', 'bert.encoder.v_layer.3.attention.self.query.bias', 'bert.encoder.v_layer.3.attention.self.key.weight', 'bert.encoder.v_layer.3.attention.self.key.bias', 'bert.encoder.v_layer.3.attention.self.value.weight', 'bert.encoder.v_layer.3.attention.self.value.bias', 'bert.encoder.v_layer.3.attention.output.dense.weight', 'bert.encoder.v_layer.3.attention.output.dense.bias', 'bert.encoder.v_layer.3.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.3.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.3.intermediate.dense.weight', 'bert.encoder.v_layer.3.intermediate.dense.bias', 'bert.encoder.v_layer.3.output.dense.weight', 'bert.encoder.v_layer.3.output.dense.bias', 'bert.encoder.v_layer.3.output.LayerNorm.weight', 'bert.encoder.v_layer.3.output.LayerNorm.bias', 'bert.encoder.v_layer.4.attention.self.query.weight', 'bert.encoder.v_layer.4.attention.self.query.bias', 'bert.encoder.v_layer.4.attention.self.key.weight', 'bert.encoder.v_layer.4.attention.self.key.bias', 'bert.encoder.v_layer.4.attention.self.value.weight', 'bert.encoder.v_layer.4.atte ...
# 2020-11-06T08:24:50 | transformers.modeling_utils: Weights from pretrained model not used in ViLBERTBase: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# 2020-11-06T08:24:50 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-06T08:24:50 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-06T08:24:50 | mmf.utils.checkpoint: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/vilbert/vilbert.finetuned.hateful_memes_direct.tar.gz to /root/.cache/torch/mmf/data/models/vilbert.finetuned.hateful_memes.direct/vilbert.finetuned.hateful_memes_direct.tar.gz ]
# Downloading vilbert.finetuned.hateful_memes_direct.tar.gz: 100% 918M/918M [00:16<00:00, 56.4MB/s]
# [ Starting checksum for vilbert.finetuned.hateful_memes_direct.tar.gz]
# [ Checksum successful for vilbert.finetuned.hateful_memes_direct.tar.gz]
# Unpacking vilbert.finetuned.hateful_memes_direct.tar.gz
# WARNING 2020-11-06T08:25:19 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:25:19 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:25:19 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:25:19 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:25:20 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:25:20 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:25:20 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# WARNING 2020-11-06T08:25:20 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# 2020-11-06T08:25:20 | mmf.utils.checkpoint: Checkpoint loaded.
# 2020-11-06T08:25:20 | mmf.utils.checkpoint: Current num updates: 0
# 2020-11-06T08:25:20 | mmf.utils.checkpoint: Current iteration: 0
# 2020-11-06T08:25:20 | mmf.utils.checkpoint: Current epoch: 0
# 2020-11-06T08:25:20 | mmf.trainers.core.evaluation_loop: Starting val inference predictions
# 2020-11-06T08:25:20 | mmf.common.test_reporter: Predicting for hateful_memes
# 100% 16/16 [03:46<00:00, 14.18s/it]
# 2020-11-06T08:29:07 | mmf.common.test_reporter: Wrote predictions for hateful_memes to /content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_val_2020-11-06T08:29:07.csv
# 2020-11-06T08:29:07 | mmf.trainers.core.evaluation_loop: Finished predicting

# %%
#visual bert - validate files - uni modal
# !mmf_predict config=projects/hateful_memes/configs/visual_bert/direct.yaml model=visual_bert dataset=hateful_memes run_type=val checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.direct dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-11-08 06:36:31.010595: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# 2020-11-08T06:36:33 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/visual_bert/direct.yaml
# 2020-11-08T06:36:33 | mmf.utils.configuration: Overriding option model to visual_bert
# 2020-11-08T06:36:33 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-08T06:36:33 | mmf.utils.configuration: Overriding option run_type to val
# 2020-11-08T06:36:33 | mmf.utils.configuration: Overriding option checkpoint.resume_zoo to visual_bert.finetuned.hateful_memes.direct
# 2020-11-08T06:36:33 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-11-08T06:36:33 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-11-08T06:36:33 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-11-08T06:36:33 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-11-08T06:36:33 | mmf: Logging to: ./save/train.log
# 2020-11-08T06:36:33 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/visual_bert/direct.yaml', 'model=visual_bert', 'dataset=hateful_memes', 'run_type=val', 'checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.direct', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-11-08T06:36:33 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-08T06:36:33 | mmf_cli.run: Using seed 33795911
# 2020-11-08T06:36:33 | mmf.trainers.mmf_trainer: Loading datasets
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/datasets/hateful_memes/defaults/features/features_2020_10_01.tar.gz to /root/.cache/torch/mmf/data/datasets/hateful_memes/defaults/features/features.tar.gz ]
# Downloading features.tar.gz: 100% 10.3G/10.3G [14:57<00:00, 11.5MB/s]
# [ Starting checksum for features.tar.gz]
# [ Checksum successful for features.tar.gz]
# Unpacking features.tar.gz
# 2020-11-08T06:57:06 | transformers.file_utils: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt not found in cache or force_download set to True, downloading to /tmp/tmpcwhxtp21
# 2020-11-08T06:57:07 | transformers.file_utils: copying /tmp/tmpcwhxtp21 to cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-08T06:57:07 | transformers.file_utils: creating metadata file for /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-08T06:57:07 | transformers.file_utils: removing temp file /tmp/tmpcwhxtp21
# 2020-11-08T06:57:07 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-08T06:57:10 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-08T06:57:10 | transformers.file_utils: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin not found in cache or force_download set to True, downloading to /tmp/tmps0jne6q_
# 2020-11-08T06:57:27 | transformers.file_utils: copying /tmp/tmps0jne6q_ to cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-08T06:57:28 | transformers.file_utils: creating metadata file for /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-08T06:57:28 | transformers.file_utils: removing temp file /tmp/tmps0jne6q_
# 2020-11-08T06:57:28 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-08T06:57:32 | transformers.modeling_utils: Weights of VisualBERTBase not initialized from pretrained model: ['bert.embeddings.token_type_embeddings_visual.weight', 'bert.embeddings.position_embeddings_visual.weight', 'bert.embeddings.projection.weight', 'bert.embeddings.projection.bias']
# 2020-11-08T06:57:32 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-08T06:57:32 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-08T06:57:32 | mmf.utils.checkpoint: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/visual_bert/visual_bert.finetuned.hateful_memes_direct.tar.gz to /root/.cache/torch/mmf/data/models/visual_bert.finetuned.hateful_memes.direct/visual_bert.finetuned.hateful_memes_direct.tar.gz ]
# Downloading visual_bert.finetuned.hateful_memes_direct.tar.gz: 100% 415M/415M [00:36<00:00, 11.4MB/s]
# [ Starting checksum for visual_bert.finetuned.hateful_memes_direct.tar.gz]
# [ Checksum successful for visual_bert.finetuned.hateful_memes_direct.tar.gz]
# Unpacking visual_bert.finetuned.hateful_memes_direct.tar.gz
# WARNING 2020-11-08T06:58:15 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-08T06:58:15 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-08T06:58:15 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-08T06:58:15 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-08T06:58:15 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-08T06:58:15 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-08T06:58:15 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# WARNING 2020-11-08T06:58:15 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# 2020-11-08T06:58:15 | mmf.utils.checkpoint: Checkpoint loaded.
# 2020-11-08T06:58:15 | mmf.utils.checkpoint: Current num updates: 0
# 2020-11-08T06:58:15 | mmf.utils.checkpoint: Current iteration: 0
# 2020-11-08T06:58:15 | mmf.utils.checkpoint: Current epoch: 0
# 2020-11-08T06:58:15 | mmf.trainers.core.evaluation_loop: Starting val inference predictions
# 2020-11-08T06:58:15 | mmf.common.test_reporter: Predicting for hateful_memes
# 100% 4/4 [03:27<00:00, 51.97s/it]
# 2020-11-08T07:01:43 | mmf.common.test_reporter: Wrote predictions for hateful_memes to /content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_val_2020-11-08T07:01:43.csv
# 2020-11-08T07:01:43 | mmf.trainers.core.evaluation_loop: Finished predicting

# %%
#visual bert - validate files - multimodal
# !mmf_predict config=projects/hateful_memes/configs/visual_bert/direct.yaml model=visual_bert dataset=hateful_memes run_type=val checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.from_coco dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-11-06 08:32:39.725979: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# 2020-11-06T08:32:42 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/visual_bert/direct.yaml
# 2020-11-06T08:32:42 | mmf.utils.configuration: Overriding option model to visual_bert
# 2020-11-06T08:32:42 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-06T08:32:42 | mmf.utils.configuration: Overriding option run_type to val
# 2020-11-06T08:32:42 | mmf.utils.configuration: Overriding option checkpoint.resume_zoo to visual_bert.finetuned.hateful_memes.from_coco
# 2020-11-06T08:32:42 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-11-06T08:32:42 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-11-06T08:32:42 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-11-06T08:32:42 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-11-06T08:32:42 | mmf: Logging to: ./save/train.log
# 2020-11-06T08:32:42 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/visual_bert/direct.yaml', 'model=visual_bert', 'dataset=hateful_memes', 'run_type=val', 'checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.from_coco', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-11-06T08:32:42 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-06T08:32:42 | mmf_cli.run: Using seed 42266661
# 2020-11-06T08:32:42 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-11-06T08:32:43 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-06T08:32:46 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-06T08:32:46 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-06T08:32:50 | transformers.modeling_utils: Weights of VisualBERTBase not initialized from pretrained model: ['bert.embeddings.token_type_embeddings_visual.weight', 'bert.embeddings.position_embeddings_visual.weight', 'bert.embeddings.projection.weight', 'bert.embeddings.projection.bias']
# 2020-11-06T08:32:50 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-06T08:32:50 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-06T08:32:50 | mmf.utils.checkpoint: Loading checkpoint
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/models/visual_bert/visual_bert.finetuned.hateful_memes_from_coco.tar.gz to /root/.cache/torch/mmf/data/models/visual_bert.finetuned.hateful_memes.from_coco/visual_bert.finetuned.hateful_memes_from_coco.tar.gz ]
# Downloading visual_bert.finetuned.hateful_memes_from_coco.tar.gz: 100% 414M/414M [00:08<00:00, 50.5MB/s]
# [ Starting checksum for visual_bert.finetuned.hateful_memes_from_coco.tar.gz]
# [ Checksum successful for visual_bert.finetuned.hateful_memes_from_coco.tar.gz]
# Unpacking visual_bert.finetuned.hateful_memes_from_coco.tar.gz
# WARNING 2020-11-06T08:33:05 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:33:05 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:33:05 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:33:05 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:33:05 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:33:05 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:33:05 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# WARNING 2020-11-06T08:33:05 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# 2020-11-06T08:33:05 | mmf.utils.checkpoint: Checkpoint loaded.
# 2020-11-06T08:33:05 | mmf.utils.checkpoint: Current num updates: 0
# 2020-11-06T08:33:05 | mmf.utils.checkpoint: Current iteration: 0
# 2020-11-06T08:33:05 | mmf.utils.checkpoint: Current epoch: 0
# 2020-11-06T08:33:05 | mmf.trainers.core.evaluation_loop: Starting val inference predictions
# 2020-11-06T08:33:05 | mmf.common.test_reporter: Predicting for hateful_memes
# 100% 4/4 [03:09<00:00, 47.29s/it]
# 2020-11-06T08:36:14 | mmf.common.test_reporter: Wrote predictions for hateful_memes to /content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_val_2020-11-06T08:36:14.csv
# 2020-11-06T08:36:14 | mmf.trainers.core.evaluation_loop: Finished predicting

# %%
#visual bert - test - unimodal
# !mmf_predict config=projects/hateful_memes/configs/visual_bert/direct.yaml model=visual_bert dataset=hateful_memes run_type=test checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.direct dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-11-06 08:50:48.665070: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# 2020-11-06T08:50:51 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/visual_bert/direct.yaml
# 2020-11-06T08:50:51 | mmf.utils.configuration: Overriding option model to visual_bert
# 2020-11-06T08:50:51 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-06T08:50:51 | mmf.utils.configuration: Overriding option run_type to test
# 2020-11-06T08:50:51 | mmf.utils.configuration: Overriding option checkpoint.resume_zoo to visual_bert.finetuned.hateful_memes.direct
# 2020-11-06T08:50:51 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-11-06T08:50:51 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-11-06T08:50:51 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-11-06T08:50:51 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-11-06T08:50:51 | mmf: Logging to: ./save/train.log
# 2020-11-06T08:50:51 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/visual_bert/direct.yaml', 'model=visual_bert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.direct', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-11-06T08:50:51 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-06T08:50:51 | mmf_cli.run: Using seed 51176407
# 2020-11-06T08:50:51 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-11-06T08:50:52 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-06T08:50:55 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-06T08:50:55 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-06T08:50:59 | transformers.modeling_utils: Weights of VisualBERTBase not initialized from pretrained model: ['bert.embeddings.token_type_embeddings_visual.weight', 'bert.embeddings.position_embeddings_visual.weight', 'bert.embeddings.projection.weight', 'bert.embeddings.projection.bias']
# 2020-11-06T08:50:59 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-06T08:50:59 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-06T08:50:59 | mmf.utils.checkpoint: Loading checkpoint
# WARNING 2020-11-06T08:51:12 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:51:12 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:51:12 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:51:12 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:51:12 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:51:12 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:51:12 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# WARNING 2020-11-06T08:51:12 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# 2020-11-06T08:51:12 | mmf.utils.checkpoint: Checkpoint loaded.
# 2020-11-06T08:51:12 | mmf.utils.checkpoint: Current num updates: 0
# 2020-11-06T08:51:12 | mmf.utils.checkpoint: Current iteration: 0
# 2020-11-06T08:51:12 | mmf.utils.checkpoint: Current epoch: 0
# 2020-11-06T08:51:12 | mmf.trainers.core.evaluation_loop: Starting test inference predictions
# 2020-11-06T08:51:12 | mmf.common.test_reporter: Predicting for hateful_memes
# 100% 8/8 [06:12<00:00, 46.55s/it]
# 2020-11-06T08:57:25 | mmf.common.test_reporter: Wrote predictions for hateful_memes to /content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_test_2020-11-06T08:57:25.csv
# 2020-11-06T08:57:25 | mmf.trainers.core.evaluation_loop: Finished predicting

# %%
#visual bert - test - multimodal
# !mmf_predict config=projects/hateful_memes/configs/visual_bert/direct.yaml model=visual_bert dataset=hateful_memes run_type=test checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.from_coco dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-11-06 08:41:05.803469: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# 2020-11-06T08:41:08 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/visual_bert/direct.yaml
# 2020-11-06T08:41:08 | mmf.utils.configuration: Overriding option model to visual_bert
# 2020-11-06T08:41:08 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-06T08:41:08 | mmf.utils.configuration: Overriding option run_type to test
# 2020-11-06T08:41:08 | mmf.utils.configuration: Overriding option checkpoint.resume_zoo to visual_bert.finetuned.hateful_memes.from_coco
# 2020-11-06T08:41:08 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-11-06T08:41:08 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-11-06T08:41:08 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-11-06T08:41:08 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-11-06T08:41:08 | mmf: Logging to: ./save/train.log
# 2020-11-06T08:41:08 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/visual_bert/direct.yaml', 'model=visual_bert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume_zoo=visual_bert.finetuned.hateful_memes.from_coco', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-11-06T08:41:08 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-06T08:41:08 | mmf_cli.run: Using seed 8225636
# 2020-11-06T08:41:08 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-11-06T08:41:09 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-06T08:41:12 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-06T08:41:12 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-06T08:41:16 | transformers.modeling_utils: Weights of VisualBERTBase not initialized from pretrained model: ['bert.embeddings.token_type_embeddings_visual.weight', 'bert.embeddings.position_embeddings_visual.weight', 'bert.embeddings.projection.weight', 'bert.embeddings.projection.bias']
# 2020-11-06T08:41:16 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-06T08:41:16 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-06T08:41:16 | mmf.utils.checkpoint: Loading checkpoint
# WARNING 2020-11-06T08:41:17 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:41:17 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:41:17 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-11-06T08:41:17 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-11-06T08:41:17 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:41:17 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:255: UserWarning: 'optimizer' key is not present in the checkpoint asked to be loaded. Skipping.
#   "'optimizer' key is not present in the "
#
# WARNING 2020-11-06T08:41:17 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# WARNING 2020-11-06T08:41:17 | py.warnings: /usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py:298: UserWarning: 'lr_scheduler' key is not present in the checkpoint asked to be loaded. Setting lr_scheduler's last_epoch to current_iteration.
#   "'lr_scheduler' key is not present in the "
#
# 2020-11-06T08:41:17 | mmf.utils.checkpoint: Checkpoint loaded.
# 2020-11-06T08:41:17 | mmf.utils.checkpoint: Current num updates: 0
# 2020-11-06T08:41:17 | mmf.utils.checkpoint: Current iteration: 0
# 2020-11-06T08:41:17 | mmf.utils.checkpoint: Current epoch: 0
# 2020-11-06T08:41:18 | mmf.trainers.core.evaluation_loop: Starting test inference predictions
# 2020-11-06T08:41:18 | mmf.common.test_reporter: Predicting for hateful_memes
# 100% 8/8 [06:10<00:00, 46.26s/it]
# 2020-11-06T08:47:28 | mmf.common.test_reporter: Wrote predictions for hateful_memes to /content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_test_2020-11-06T08:47:28.csv
# 2020-11-06T08:47:28 | mmf.trainers.core.evaluation_loop: Finished predicting

# %%
#get roc and auc for dev (validation)
from sklearn import metrics
import json
import numpy as np
import pandas as pd

def load_tester(path):
    data = pd.read_json(path,lines=True)
    arr2D = np.asarray(data)
    return arr2D[arr2D[:,0].argsort()]

def load_tester_csv(path):
    data = pd.read_csv(path)
    arr2D = np.asarray(data)
    return arr2D[arr2D[:,0].argsort()]

read_test_true = '/root/.cache/torch/mmf/data/datasets/hateful_memes/defaults/annotations/dev_seen.jsonl'
ground_truth = load_tester(read_test_true)

read_pred = '/content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_val_mmbt_grid.csv'
pred_score = load_tester_csv(read_pred)

print(ground_truth[:,2].sum())
print(pred_score[:,2].sum())

print("ROC")
print(metrics.roc_auc_score(ground_truth[:,2].astype(bool), pred_score[:,1]))
print("accuracy")
print(metrics.accuracy_score(ground_truth[:,2].astype(bool), pred_score[:,2].astype(bool)))
# Out:
# 247
# 119.0
# ROC
# 0.7063577155110335
# accuracy
# 0.608

# %% [markdown]
# ## Train an existing model
#
# We will use MMF to train an existing baseline from MMF's model zoo on the Hateful Memes dataset. Run the next code cell to start training MMBT-Grid model on the dataset. You can adjust the batch size, maximum number of updates, log and evaluation interval among other things by using command line overrides. Read more about MMF's configuration system at https://mmf.readthedocs.io/en/latest/notes/configuration.html.

# %%
# !mmf_run config=projects/hateful_memes/configs/mmbt/defaults.yaml \
  model=mmbt \
  dataset=hateful_memes \
  training.log_interval=50 \
  training.max_updates=3000 \
  training.batch_size=16 \
  training.evaluation_interval=500
# Out:
# 2020-10-31 10:40:37.991009: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-31T10:40:42 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/mmbt/defaults.yaml
# 2020-10-31T10:40:42 | mmf.utils.configuration: Overriding option model to mmbt
# 2020-10-31T10:40:42 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-10-31T10:40:42 | mmf.utils.configuration: Overriding option training.log_interval to 50
# 2020-10-31T10:40:42 | mmf.utils.configuration: Overriding option training.max_updates to 3000
# 2020-10-31T10:40:42 | mmf.utils.configuration: Overriding option training.batch_size to 16
# 2020-10-31T10:40:42 | mmf.utils.configuration: Overriding option training.evaluation_interval to 500
# 2020-10-31T10:40:42 | mmf: Logging to: ./save/train.log
# 2020-10-31T10:40:42 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/mmbt/defaults.yaml', 'model=mmbt', 'dataset=hateful_memes', 'training.log_interval=50', 'training.max_updates=3000', 'training.batch_size=16', 'training.evaluation_interval=500'])
# 2020-10-31T10:40:42 | mmf_cli.run: Torch version: 1.6.0+cu101
# 2020-10-31T10:40:42 | mmf.utils.general: CUDA Device 0 is: Tesla V100-SXM2-16GB
# 2020-10-31T10:40:42 | mmf_cli.run: Using seed 43032745
# 2020-10-31T10:40:42 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-10-31T10:40:44 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-10-31T10:40:47 | mmf.trainers.mmf_trainer: Loading model
# 2020-10-31T10:40:47 | transformers.file_utils: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpry9sf1x9
# 2020-10-31T10:40:48 | transformers.file_utils: copying /tmp/tmpry9sf1x9 to cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2020-10-31T10:40:48 | transformers.file_utils: creating metadata file for /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2020-10-31T10:40:48 | transformers.file_utils: removing temp file /tmp/tmpry9sf1x9
# 2020-10-31T10:40:48 | transformers.configuration_utils: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2020-10-31T10:40:48 | transformers.configuration_utils: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 2020-10-31T10:40:48 | transformers.file_utils: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin not found in cache or force_download set to True, downloading to /tmp/tmp9gggzz55
# 2020-10-31T10:41:05 | transformers.file_utils: copying /tmp/tmp9gggzz55 to cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-10-31T10:41:06 | transformers.file_utils: creating metadata file for /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-10-31T10:41:06 | transformers.file_utils: removing temp file /tmp/tmp9gggzz55
# 2020-10-31T10:41:06 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /root/.cache/torch/hub/checkpoints/resnet152-b121ed2d.pth
# 100% 230M/230M [00:11<00:00, 20.6MB/s]
# 2020-10-31T10:41:32 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-10-31T10:41:32 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-10-31T10:41:32 | mmf.trainers.mmf_trainer: ===== Model =====
# 2020-10-31T10:41:32 | mmf.trainers.mmf_trainer: MMBT(
#   (model): MMBTForClassification(
#     (bert): MMBTBase(
#       (mmbt): MMBTModel(
#         (transformer): BertModelJit(
#           (embeddings): BertEmbeddingsJit(
#             (word_embeddings): Embedding(30522, 768, padding_idx=0)
#             (position_embeddings): Embedding(512, 768)
#             (token_type_embeddings): Embedding(2, 768)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (encoder): BertEncoderJit(
#             (layer): ModuleList(
#               (0): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (1): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (2): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (3): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (4): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (5): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (6): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (7): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (8): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (9): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (10): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (11): BertLayerJit(
#                 (attention): BertAttentionJit(
#                   (self): BertSelfAttentionJit(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): BertSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): BertIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 )
#                 (output): BertOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#             )
#           )
#           (pooler): BertPooler(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (activation): Tanh()
#           )
#         )
#         (modal_encoder): ModalEmbeddings(
#           (encoder): ResNet152ImageEncoder(
#             (model): Sequential(
#               (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#               (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#               (4): Sequential(
#                 (0): Bottleneck(
#                   (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                   (downsample): Sequential(
#                     (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   )
#                 )
#                 (1): Bottleneck(
#                   (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (2): Bottleneck(
#                   (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#               )
#               (5): Sequential(
#                 (0): Bottleneck(
#                   (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                   (downsample): Sequential(
#                     (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   )
#                 )
#                 (1): Bottleneck(
#                   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (2): Bottleneck(
#                   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (3): Bottleneck(
#                   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (4): Bottleneck(
#                   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (5): Bottleneck(
#                   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (6): Bottleneck(
#                   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (7): Bottleneck(
#                   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#               )
#               (6): Sequential(
#                 (0): Bottleneck(
#                   (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                   (downsample): Sequential(
#                     (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   )
#                 )
#                 (1): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (2): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (3): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (4): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (5): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (6): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (7): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (8): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (9): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (10): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (11): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (12): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (13): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (14): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (15): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (16): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (17): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (18): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (19): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (20): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (21): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (22): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (23): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (24): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (relu): ReLU(inplace=True)
#                 )
#                 (25): Bottleneck(
#                   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
# 2020-10-31T10:44:18 | mmf.trainers.callbacks.logistics: progress: 400/3000, train/hateful_memes/cross_entropy: 0.7438, train/hateful_memes/cross_entropy/avg: 0.7138, train/total_loss: 0.7438, train/total_loss/avg: 0.7138, max mem: 7795.0, experiment: run, epoch: 1, num_updates: 400, iterations: 400, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 476ms, time_since_start: 02m 45s 501ms, eta: 17m 49s 014ms
# 2020-10-31T10:44:38 | mmf.trainers.callbacks.logistics: progress: 450/3000, train/hateful_memes/cross_entropy: 0.7438, train/hateful_memes/cross_entropy/avg: 0.7132, train/total_loss: 0.7438, train/total_loss/avg: 0.7132, max mem: 7795.0, experiment: run, epoch: 1, num_updates: 450, iterations: 450, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 228ms, time_since_start: 03m 05s 730ms, eta: 17m 15s 787ms
# 2020-10-31T10:44:58 | mmf.trainers.callbacks.logistics: progress: 500/3000, train/hateful_memes/cross_entropy: 0.7078, train/hateful_memes/cross_entropy/avg: 0.7005, train/total_loss: 0.7078, train/total_loss/avg: 0.7005, max mem: 7795.0, experiment: run, epoch: 1, num_updates: 500, iterations: 500, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 240ms, time_since_start: 03m 25s 970ms, eta: 16m 56s 065ms
# 2020-10-31T10:44:58 | mmf.trainers.core.training_loop: Evaluation time. Running on full validation set...
# WARNING 2020-10-31T10:45:08 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:200: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# WARNING 2020-10-31T10:45:08 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:200: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# 2020-10-31T10:46:08 | mmf.trainers.callbacks.logistics: progress: 500/3000, val/hateful_memes/cross_entropy: 0.6691, val/total_loss: 0.6691, val/hateful_memes/accuracy: 0.6278, val/hateful_memes/binary_f1: 0.3410, val/hateful_memes/roc_auc: 0.5696, num_updates: 500, epoch: 1, iterations: 500, max_updates: 3000, val_time: 01m 10s 026ms, best_update: 500, best_iteration: 500, best_val/hateful_memes/roc_auc: 0.569588
# 2020-10-31T10:46:31 | mmf.trainers.callbacks.logistics: progress: 550/3000, train/hateful_memes/cross_entropy: 0.7078, train/hateful_memes/cross_entropy/avg: 0.6768, train/total_loss: 0.7078, train/total_loss/avg: 0.6768, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 550, iterations: 550, max_updates: 3000, lr: 0., ups: 2.27, time: 22s 995ms, time_since_start: 04m 58s 994ms, eta: 18m 51s 302ms
# 2020-10-31T10:46:52 | mmf.trainers.callbacks.logistics: progress: 600/3000, train/hateful_memes/cross_entropy: 0.6221, train/hateful_memes/cross_entropy/avg: 0.6544, train/total_loss: 0.6221, train/total_loss/avg: 0.6544, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 600, iterations: 600, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 190ms, time_since_start: 05m 19s 185ms, eta: 16m 13s 027ms
# 2020-10-31T10:47:12 | mmf.trainers.callbacks.logistics: progress: 650/3000, train/hateful_memes/cross_entropy: 0.6221, train/hateful_memes/cross_entropy/avg: 0.6424, train/total_loss: 0.6221, train/total_loss/avg: 0.6424, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 650, iterations: 650, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 250ms, time_since_start: 05m 39s 436ms, eta: 15m 55s 591ms
# 2020-10-31T10:47:32 | mmf.trainers.callbacks.logistics: progress: 700/3000, train/hateful_memes/cross_entropy: 0.6036, train/hateful_memes/cross_entropy/avg: 0.6376, train/total_loss: 0.6036, train/total_loss/avg: 0.6376, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 700, iterations: 700, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 550ms, time_since_start: 05m 59s 986ms, eta: 15m 49s 125ms
# 2020-10-31T10:47:53 | mmf.trainers.callbacks.logistics: progress: 750/3000, train/hateful_memes/cross_entropy: 0.6036, train/hateful_memes/cross_entropy/avg: 0.6339, train/total_loss: 0.6036, train/total_loss/avg: 0.6339, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 750, iterations: 750, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 333ms, time_since_start: 06m 20s 320ms, eta: 15m 18s 680ms
# 2020-10-31T10:48:13 | mmf.trainers.callbacks.logistics: progress: 800/3000, train/hateful_memes/cross_entropy: 0.6036, train/hateful_memes/cross_entropy/avg: 0.6364, train/total_loss: 0.6036, train/total_loss/avg: 0.6364, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 800, iterations: 800, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 471ms, time_since_start: 06m 40s 791ms, eta: 15m 04s 329ms
# 2020-10-31T10:48:34 | mmf.trainers.callbacks.logistics: progress: 850/3000, train/hateful_memes/cross_entropy: 0.6036, train/hateful_memes/cross_entropy/avg: 0.6206, train/total_loss: 0.6036, train/total_loss/avg: 0.6206, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 850, iterations: 850, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 350ms, time_since_start: 07m 01s 142ms, eta: 14m 38s 594ms
# 2020-10-31T10:48:54 | mmf.trainers.callbacks.logistics: progress: 900/3000, train/hateful_memes/cross_entropy: 0.5867, train/hateful_memes/cross_entropy/avg: 0.6131, train/total_loss: 0.5867, train/total_loss/avg: 0.6131, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 900, iterations: 900, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 282ms, time_since_start: 07m 21s 425ms, eta: 14m 15s 287ms
# 2020-10-31T10:49:14 | mmf.trainers.callbacks.logistics: progress: 950/3000, train/hateful_memes/cross_entropy: 0.5867, train/hateful_memes/cross_entropy/avg: 0.6113, train/total_loss: 0.5867, train/total_loss/avg: 0.6113, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 950, iterations: 950, max_updates: 3000, lr: 0., ups: 2.50, time: 20s 604ms, time_since_start: 07m 42s 030ms, eta: 14m 08s 167ms
# 2020-10-31T10:49:35 | mmf.trainers.callbacks.checkpoint: Checkpoint time. Saving a checkpoint.
# 2020-10-31T10:50:11 | mmf.trainers.callbacks.logistics: progress: 1000/3000, train/hateful_memes/cross_entropy: 0.5867, train/hateful_memes/cross_entropy/avg: 0.6102, train/total_loss: 0.5867, train/total_loss/avg: 0.6102, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 1000, iterations: 1000, max_updates: 3000, lr: 0.00001, ups: 0.89, time: 56s 158ms, time_since_start: 08m 38s 188ms, eta: 37m 35s 314ms
# 2020-10-31T10:50:11 | mmf.trainers.core.training_loop: Evaluation time. Running on full validation set...
# WARNING 2020-10-31T10:50:20 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:200: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# WARNING 2020-10-31T10:50:20 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:200: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# 2020-10-31T10:51:26 | mmf.trainers.callbacks.logistics: progress: 1000/3000, val/hateful_memes/cross_entropy: 0.7217, val/total_loss: 0.7217, val/hateful_memes/accuracy: 0.6019, val/hateful_memes/binary_f1: 0.3131, val/hateful_memes/roc_auc: 0.5999, num_updates: 1000, epoch: 2, iterations: 1000, max_updates: 3000, val_time: 01m 15s 194ms, best_update: 1000, best_iteration: 1000, best_val/hateful_memes/roc_auc: 0.599941
# 2020-10-31T10:51:48 | mmf.trainers.callbacks.logistics: progress: 1050/3000, train/hateful_memes/cross_entropy: 0.5819, train/hateful_memes/cross_entropy/avg: 0.6063, train/total_loss: 0.5819, train/total_loss/avg: 0.6063, max mem: 7795.0, experiment: run, epoch: 2, num_updates: 1050, iterations: 1050, max_updates: 3000, lr: 0.00001, ups: 2.38, time: 21s 917ms, time_since_start: 10m 15s 534ms, eta: 14m 18s 209ms
# 2020-10-31T10:52:10 | mmf.trainers.callbacks.logistics: progress: 1100/3000, train/hateful_memes/cross_entropy: 0.5794, train/hateful_memes/cross_entropy/avg: 0.5954, train/total_loss: 0.5794, train/total_loss/avg: 0.5954, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1100, iterations: 1100, max_updates: 3000, lr: 0.00001, ups: 2.27, time: 22s 435ms, time_since_start: 10m 37s 970ms, eta: 14m 15s 950ms
# 2020-10-31T10:52:31 | mmf.trainers.callbacks.logistics: progress: 1150/3000, train/hateful_memes/cross_entropy: 0.5751, train/hateful_memes/cross_entropy/avg: 0.5874, train/total_loss: 0.5751, train/total_loss/avg: 0.5874, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1150, iterations: 1150, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 394ms, time_since_start: 10m 58s 364ms, eta: 12m 37s 624ms
# 2020-10-31T10:52:51 | mmf.trainers.callbacks.logistics: progress: 1200/3000, train/hateful_memes/cross_entropy: 0.5794, train/hateful_memes/cross_entropy/avg: 0.5881, train/total_loss: 0.5794, train/total_loss/avg: 0.5881, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1200, iterations: 1200, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 464ms, time_since_start: 11m 18s 829ms, eta: 12m 19s 683ms
# 2020-10-31T10:53:11 | mmf.trainers.callbacks.logistics: progress: 1250/3000, train/hateful_memes/cross_entropy: 0.5751, train/hateful_memes/cross_entropy/avg: 0.5824, train/total_loss: 0.5751, train/total_loss/avg: 0.5824, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1250, iterations: 1250, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 300ms, time_since_start: 11m 39s 130ms, eta: 11m 53s 346ms
# 2020-10-31T10:53:32 | mmf.trainers.callbacks.logistics: progress: 1300/3000, train/hateful_memes/cross_entropy: 0.5751, train/hateful_memes/cross_entropy/avg: 0.5908, train/total_loss: 0.5751, train/total_loss/avg: 0.5908, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1300, iterations: 1300, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 351ms, time_since_start: 11m 59s 481ms, eta: 11m 34s 712ms
# 2020-10-31T10:53:52 | mmf.trainers.callbacks.logistics: progress: 1350/3000, train/hateful_memes/cross_entropy: 0.5751, train/hateful_memes/cross_entropy/avg: 0.6003, train/total_loss: 0.5751, train/total_loss/avg: 0.6003, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1350, iterations: 1350, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 298ms, time_since_start: 12m 19s 780ms, eta: 11m 12s 537ms
# 2020-10-31T10:54:12 | mmf.trainers.callbacks.logistics: progress: 1400/3000, train/hateful_memes/cross_entropy: 0.5283, train/hateful_memes/cross_entropy/avg: 0.5870, train/total_loss: 0.5283, train/total_loss/avg: 0.5870, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1400, iterations: 1400, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 303ms, time_since_start: 12m 40s 083ms, eta: 10m 52s 323ms
# 2020-10-31T10:54:33 | mmf.trainers.callbacks.logistics: progress: 1450/3000, train/hateful_memes/cross_entropy: 0.4977, train/hateful_memes/cross_entropy/avg: 0.5772, train/total_loss: 0.4977, train/total_loss/avg: 0.5772, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1450, iterations: 1450, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 447ms, time_since_start: 13m 531ms, eta: 10m 36s 407ms
# 2020-10-31T10:54:54 | mmf.trainers.callbacks.logistics: progress: 1500/3000, train/hateful_memes/cross_entropy: 0.4854, train/hateful_memes/cross_entropy/avg: 0.5733, train/total_loss: 0.4854, train/total_loss/avg: 0.5733, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1500, iterations: 1500, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 603ms, time_since_start: 13m 21s 135ms, eta: 10m 20s 588ms
# 2020-10-31T10:54:54 | mmf.trainers.core.training_loop: Evaluation time. Running on full validation set...
# WARNING 2020-10-31T10:55:03 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:200: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# WARNING 2020-10-31T10:55:03 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:200: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# 2020-10-31T10:56:04 | mmf.trainers.callbacks.logistics: progress: 1500/3000, val/hateful_memes/cross_entropy: 0.8174, val/total_loss: 0.8174, val/hateful_memes/accuracy: 0.6370, val/hateful_memes/binary_f1: 0.1833, val/hateful_memes/roc_auc: 0.6212, num_updates: 1500, epoch: 3, iterations: 1500, max_updates: 3000, val_time: 01m 10s 073ms, best_update: 1500, best_iteration: 1500, best_val/hateful_memes/roc_auc: 0.621176
# 2020-10-31T10:56:25 | mmf.trainers.callbacks.logistics: progress: 1550/3000, train/hateful_memes/cross_entropy: 0.4977, train/hateful_memes/cross_entropy/avg: 0.5730, train/total_loss: 0.4977, train/total_loss/avg: 0.5730, max mem: 7795.0, experiment: run, epoch: 3, num_updates: 1550, iterations: 1550, max_updates: 3000, lr: 0.00001, ups: 2.38, time: 21s 053ms, time_since_start: 14m 52s 263ms, eta: 10m 13s 004ms
# 2020-10-31T10:56:47 | mmf.trainers.callbacks.logistics: progress: 1600/3000, train/hateful_memes/cross_entropy: 0.4977, train/hateful_memes/cross_entropy/avg: 0.5686, train/total_loss: 0.4977, train/total_loss/avg: 0.5686, max mem: 7795.0, experiment: run, epoch: 4, num_updates: 1600, iterations: 1600, max_updates: 3000, lr: 0.00001, ups: 2.38, time: 21s 955ms, time_since_start: 15m 14s 219ms, eta: 10m 17s 210ms
# 2020-10-31T10:57:07 | mmf.trainers.callbacks.logistics: progress: 1650/3000, train/hateful_memes/cross_entropy: 0.4854, train/hateful_memes/cross_entropy/avg: 0.5572, train/total_loss: 0.4854, train/total_loss/avg: 0.5572, max mem: 7795.0, experiment: run, epoch: 4, num_updates: 1650, iterations: 1650, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 537ms, time_since_start: 15m 34s 757ms, eta: 09m 16s 735ms
# 2020-10-31T10:57:28 | mmf.trainers.callbacks.logistics: progress: 1700/3000, train/hateful_memes/cross_entropy: 0.4607, train/hateful_memes/cross_entropy/avg: 0.5517, train/total_loss: 0.4607, train/total_loss/avg: 0.5517, max mem: 7795.0, experiment: run, epoch: 4, num_updates: 1700, iterations: 1700, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 443ms, time_since_start: 15m 55s 200ms, eta: 08m 53s 653ms
# 2020-10-31T10:57:48 | mmf.trainers.callbacks.logistics: progress: 1750/3000, train/hateful_memes/cross_entropy: 0.4478, train/hateful_memes/cross_entropy/avg: 0.5449, train/total_loss: 0.4478, train/total_loss/avg: 0.5449, max mem: 7795.0, experiment: run, epoch: 4, num_updates: 1750, iterations: 1750, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 494ms, time_since_start: 16m 15s 694ms, eta: 08m 34s 413ms
# 2020-10-31T10:58:09 | mmf.trainers.callbacks.logistics: progress: 1800/3000, train/hateful_memes/cross_entropy: 0.4299, train/hateful_memes/cross_entropy/avg: 0.5343, train/total_loss: 0.4299, train/total_loss/avg: 0.5343, max mem: 7795.0, experiment: run, epoch: 4, num_updates: 1800, iterations: 1800, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 506ms, time_since_start: 16m 36s 200ms, eta: 08m 14s 113ms
# 2020-10-31T10:58:29 | mmf.trainers.callbacks.logistics: progress: 1850/3000, train/hateful_memes/cross_entropy: 0.4478, train/hateful_memes/cross_entropy/avg: 0.5369, train/total_loss: 0.4478, train/total_loss/avg: 0.5369, max mem: 7795.0, experiment: run, epoch: 4, num_updates: 1850, iterations: 1850, max_updates: 3000, lr: 0.00001, ups: 2.50, time: 20s 425ms, time_since_start: 16m 56s 626ms, eta: 07m 51s 664ms

# %%
#run best model
# !mmf_predict config=save/config.yaml model=mmbt dataset=hateful_memes run_type=test checkpoint.resume=True training.batch_size=16 dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-10-31 11:16:50.892337: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option config to save/config.yaml
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option model to mmbt
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option run_type to test
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option checkpoint.resume to True
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option training.batch_size to 16
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-10-31T11:16:54 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-10-31T11:16:54 | mmf: Logging to: ./save/train.log
# 2020-10-31T11:16:54 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=save/config.yaml', 'model=mmbt', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume=True', 'training.batch_size=16', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-10-31T11:16:54 | mmf_cli.run: Torch version: 1.6.0+cu101
# 2020-10-31T11:16:54 | mmf.utils.general: CUDA Device 0 is: Tesla V100-SXM2-16GB
# 2020-10-31T11:16:54 | mmf_cli.run: Using seed 43032745
# 2020-10-31T11:16:54 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-10-31T11:16:56 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-10-31T11:16:58 | mmf.trainers.mmf_trainer: Loading model
# 2020-10-31T11:16:59 | transformers.configuration_utils: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2020-10-31T11:16:59 | transformers.configuration_utils: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 2020-10-31T11:16:59 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-10-31T11:17:31 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-10-31T11:17:31 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-10-31T11:17:31 | mmf.utils.checkpoint: Loading checkpoint
# WARNING 2020-10-31T11:18:27 | mmf: Key data_parallel is not present in registry, returning default value of None
# WARNING 2020-10-31T11:18:27 | mmf: Key distributed is not present in registry, returning default value of None
# WARNING 2020-10-31T11:18:28 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:218: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# WARNING 2020-10-31T11:18:28 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:218: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# 2020-10-31T11:18:28 | mmf.utils.checkpoint: Checkpoint loaded.
# 2020-10-31T11:18:28 | mmf.utils.checkpoint: Current num updates: 3000
# 2020-10-31T11:18:28 | mmf.utils.checkpoint: Current iteration: 3000
# 2020-10-31T11:18:28 | mmf.utils.checkpoint: Current epoch: 6
# 2020-10-31T11:18:28 | mmf.trainers.core.evaluation_loop: Starting test inference predictions
# 2020-10-31T11:18:28 | mmf.common.test_reporter: Predicting for hateful_memes
# 100% 63/63 [00:18<00:00,  3.38it/s]
# 2020-10-31T11:18:46 | mmf.common.test_reporter: Wrote predictions for hateful_memes to /content/drive/My Drive/msc computer science/deep learning/DL course/hateful_memes_run_test_2020-10-31T11:18:46.csv
# 2020-10-31T11:18:46 | mmf.trainers.core.evaluation_loop: Finished predicting

# %% [markdown]
# Train vibert *model*

# %%
# !mmf_run config=projects/hateful_memes/configs/vilbert/defaults.yaml \
  model=vilbert \
  dataset=hateful_memes \
  training.log_interval=50 \
  training.max_updates=3000 \
  training.batch_size=64 \
  training.evaluation_interval=500
# Out:
# 2020-11-08 10:17:58.479902: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# 2020-11-08T10:18:01 | mmf.utils.configuration: Overriding option config to projects/hateful_memes/configs/vilbert/defaults.yaml
# 2020-11-08T10:18:01 | mmf.utils.configuration: Overriding option model to vilbert
# 2020-11-08T10:18:01 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-08T10:18:01 | mmf.utils.configuration: Overriding option training.log_interval to 50
# 2020-11-08T10:18:01 | mmf.utils.configuration: Overriding option training.max_updates to 3000
# 2020-11-08T10:18:01 | mmf.utils.configuration: Overriding option training.batch_size to 64
# 2020-11-08T10:18:01 | mmf.utils.configuration: Overriding option training.evaluation_interval to 500
# 2020-11-08T10:18:01 | mmf: Logging to: ./save/train.log
# 2020-11-08T10:18:01 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=projects/hateful_memes/configs/vilbert/defaults.yaml', 'model=vilbert', 'dataset=hateful_memes', 'training.log_interval=50', 'training.max_updates=3000', 'training.batch_size=64', 'training.evaluation_interval=500'])
# 2020-11-08T10:18:01 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-08T10:18:01 | mmf_cli.run: Using seed 2044932
# 2020-11-08T10:18:01 | mmf.trainers.mmf_trainer: Loading datasets
# [ Downloading: https://dl.fbaipublicfiles.com/mmf/data/datasets/hateful_memes/defaults/features/features_2020_10_01.tar.gz to /root/.cache/torch/mmf/data/datasets/hateful_memes/defaults/features/features.tar.gz ]
# Downloading features.tar.gz: 100% 10.3G/10.3G [05:33<00:00, 30.9MB/s]
# [ Starting checksum for features.tar.gz]
# [ Checksum successful for features.tar.gz]
# Unpacking features.tar.gz
# 2020-11-08T10:27:32 | transformers.file_utils: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt not found in cache or force_download set to True, downloading to /tmp/tmpztqqros5
# 2020-11-08T10:27:32 | transformers.file_utils: copying /tmp/tmpztqqros5 to cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-08T10:27:32 | transformers.file_utils: creating metadata file for /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-08T10:27:32 | transformers.file_utils: removing temp file /tmp/tmpztqqros5
# 2020-11-08T10:27:32 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-11-08T10:27:35 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-08T10:27:35 | transformers.file_utils: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin not found in cache or force_download set to True, downloading to /tmp/tmp2_h6316m
# 2020-11-08T10:27:41 | transformers.file_utils: copying /tmp/tmp2_h6316m to cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-08T10:27:41 | transformers.file_utils: creating metadata file for /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-08T10:27:41 | transformers.file_utils: removing temp file /tmp/tmp2_h6316m
# 2020-11-08T10:27:41 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-08T10:27:45 | transformers.modeling_utils: Weights of ViLBERTBase not initialized from pretrained model: ['bert.v_embeddings.image_embeddings.weight', 'bert.v_embeddings.image_embeddings.bias', 'bert.v_embeddings.image_location_embeddings.weight', 'bert.v_embeddings.image_location_embeddings.bias', 'bert.v_embeddings.LayerNorm.weight', 'bert.v_embeddings.LayerNorm.bias', 'bert.encoder.v_layer.0.attention.self.query.weight', 'bert.encoder.v_layer.0.attention.self.query.bias', 'bert.encoder.v_layer.0.attention.self.key.weight', 'bert.encoder.v_layer.0.attention.self.key.bias', 'bert.encoder.v_layer.0.attention.self.value.weight', 'bert.encoder.v_layer.0.attention.self.value.bias', 'bert.encoder.v_layer.0.attention.output.dense.weight', 'bert.encoder.v_layer.0.attention.output.dense.bias', 'bert.encoder.v_layer.0.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.0.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.0.intermediate.dense.weight', 'bert.encoder.v_layer.0.intermediate.dense.bias', 'bert.encoder.v_layer.0.output.dense.weight', 'bert.encoder.v_layer.0.output.dense.bias', 'bert.encoder.v_layer.0.output.LayerNorm.weight', 'bert.encoder.v_layer.0.output.LayerNorm.bias', 'bert.encoder.v_layer.1.attention.self.query.weight', 'bert.encoder.v_layer.1.attention.self.query.bias', 'bert.encoder.v_layer.1.attention.self.key.weight', 'bert.encoder.v_layer.1.attention.self.key.bias', 'bert.encoder.v_layer.1.attention.self.value.weight', 'bert.encoder.v_layer.1.attention.self.value.bias', 'bert.encoder.v_layer.1.attention.output.dense.weight', 'bert.encoder.v_layer.1.attention.output.dense.bias', 'bert.encoder.v_layer.1.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.1.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.1.intermediate.dense.weight', 'bert.encoder.v_layer.1.intermediate.dense.bias', 'bert.encoder.v_layer.1.output.dense.weight', 'bert.encoder.v_layer.1.output.dense.bias', 'bert.encoder.v_layer.1.output.LayerNorm.weight', 'bert.encoder.v_layer.1.output.LayerNorm.bias', 'bert.encoder.v_layer.2.attention.self.query.weight', 'bert.encoder.v_layer.2.attention.self.query.bias', 'bert.encoder.v_layer.2.attention.self.key.weight', 'bert.encoder.v_layer.2.attention.self.key.bias', 'bert.encoder.v_layer.2.attention.self.value.weight', 'bert.encoder.v_layer.2.attention.self.value.bias', 'bert.encoder.v_layer.2.attention.output.dense.weight', 'bert.encoder.v_layer.2.attention.output.dense.bias', 'bert.encoder.v_layer.2.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.2.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.2.intermediate.dense.weight', 'bert.encoder.v_layer.2.intermediate.dense.bias', 'bert.encoder.v_layer.2.output.dense.weight', 'bert.encoder.v_layer.2.output.dense.bias', 'bert.encoder.v_layer.2.output.LayerNorm.weight', 'bert.encoder.v_layer.2.output.LayerNorm.bias', 'bert.encoder.v_layer.3.attention.self.query.weight', 'bert.encoder.v_layer.3.attention.self.query.bias', 'bert.encoder.v_layer.3.attention.self.key.weight', 'bert.encoder.v_layer.3.attention.self.key.bias', 'bert.encoder.v_layer.3.attention.self.value.weight', 'bert.encoder.v_layer.3.attention.self.value.bias', 'bert.encoder.v_layer.3.attention.output.dense.weight', 'bert.encoder.v_layer.3.attention.output.dense.bias', 'bert.encoder.v_layer.3.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.3.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.3.intermediate.dense.weight', 'bert.encoder.v_layer.3.intermediate.dense.bias', 'bert.encoder.v_layer.3.output.dense.weight', 'bert.encoder.v_layer.3.output.dense.bias', 'bert.encoder.v_layer.3.output.LayerNorm.weight', 'bert.encoder.v_layer.3.output.LayerNorm.bias', 'bert.encoder.v_layer.4.attention.self.query.weight', 'bert.encoder.v_layer.4.attention.self.query.bias', 'bert.encoder.v_layer.4.attention.self.key.weight', 'bert.encoder.v_layer.4.attention.self.key.bias', 'bert.encoder.v_layer.4.attention.self.value.weight', 'bert.encoder.v_layer.4.atte ...
# 2020-11-08T10:27:45 | transformers.modeling_utils: Weights from pretrained model not used in ViLBERTBase: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# 2020-11-08T10:27:45 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-08T10:27:45 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-08T10:27:45 | mmf.trainers.mmf_trainer: ===== Model =====
# 2020-11-08T10:27:45 | mmf.trainers.mmf_trainer: ViLBERT(
#   (model): ViLBERTForClassification(
#     (bert): ViLBERTBase(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (v_embeddings): BertImageFeatureEmbeddings(
#         (image_embeddings): Linear(in_features=2048, out_features=1024, bias=True)
#         (image_location_embeddings): Linear(in_features=5, out_features=1024, bias=True)
#         (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (v_layer): ModuleList(
#           (0): BertImageLayer(
#             (attention): BertImageAttention(
#               (self): BertImageSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertImageSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertImageLayer(
#             (attention): BertImageAttention(
#               (self): BertImageSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertImageSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertImageLayer(
#             (attention): BertImageAttention(
#               (self): BertImageSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertImageSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertImageLayer(
#             (attention): BertImageAttention(
#               (self): BertImageSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertImageSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertImageLayer(
#             (attention): BertImageAttention(
#               (self): BertImageSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertImageSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertImageLayer(
#             (attention): BertImageAttention(
#               (self): BertImageSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertImageSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (c_layer): ModuleList(
#           (0): BertConnectionLayer(
#             (biattention): BertBiAttention(
#               (query1): Linear(in_features=1024, out_features=1024, bias=True)
#               (key1): Linear(in_features=1024, out_features=1024, bias=True)
#               (value1): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (query2): Linear(in_features=768, out_features=1024, bias=True)
#               (key2): Linear(in_features=768, out_features=1024, bias=True)
#               (value2): Linear(in_features=768, out_features=1024, bias=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (biOutput): BertBiOutput(
#               (dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm1): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (q_dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_dropout1): Dropout(p=0.1, inplace=False)
#               (dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (LayerNorm2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#               (q_dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (q_dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (v_intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (v_output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (t_intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (t_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertConnectionLayer(
#             (biattention): BertBiAttention(
#               (query1): Linear(in_features=1024, out_features=1024, bias=True)
#               (key1): Linear(in_features=1024, out_features=1024, bias=True)
#               (value1): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (query2): Linear(in_features=768, out_features=1024, bias=True)
#               (key2): Linear(in_features=768, out_features=1024, bias=True)
#               (value2): Linear(in_features=768, out_features=1024, bias=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (biOutput): BertBiOutput(
#               (dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm1): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (q_dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_dropout1): Dropout(p=0.1, inplace=False)
#               (dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (LayerNorm2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#               (q_dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (q_dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (v_intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (v_output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (t_intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (t_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertConnectionLayer(
#             (biattention): BertBiAttention(
#               (query1): Linear(in_features=1024, out_features=1024, bias=True)
#               (key1): Linear(in_features=1024, out_features=1024, bias=True)
#               (value1): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (query2): Linear(in_features=768, out_features=1024, bias=True)
#               (key2): Linear(in_features=768, out_features=1024, bias=True)
#               (value2): Linear(in_features=768, out_features=1024, bias=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (biOutput): BertBiOutput(
#               (dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm1): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (q_dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_dropout1): Dropout(p=0.1, inplace=False)
#               (dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (LayerNorm2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#               (q_dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (q_dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (v_intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (v_output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (t_intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (t_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertConnectionLayer(
#             (biattention): BertBiAttention(
#               (query1): Linear(in_features=1024, out_features=1024, bias=True)
#               (key1): Linear(in_features=1024, out_features=1024, bias=True)
#               (value1): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (query2): Linear(in_features=768, out_features=1024, bias=True)
#               (key2): Linear(in_features=768, out_features=1024, bias=True)
#               (value2): Linear(in_features=768, out_features=1024, bias=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (biOutput): BertBiOutput(
#               (dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm1): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (q_dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_dropout1): Dropout(p=0.1, inplace=False)
#               (dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (LayerNorm2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#               (q_dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (q_dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (v_intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (v_output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (t_intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (t_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertConnectionLayer(
#             (biattention): BertBiAttention(
#               (query1): Linear(in_features=1024, out_features=1024, bias=True)
#               (key1): Linear(in_features=1024, out_features=1024, bias=True)
#               (value1): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (query2): Linear(in_features=768, out_features=1024, bias=True)
#               (key2): Linear(in_features=768, out_features=1024, bias=True)
#               (value2): Linear(in_features=768, out_features=1024, bias=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (biOutput): BertBiOutput(
#               (dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm1): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (q_dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_dropout1): Dropout(p=0.1, inplace=False)
#               (dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (LayerNorm2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#               (q_dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (q_dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (v_intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (v_output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (t_intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (t_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertConnectionLayer(
#             (biattention): BertBiAttention(
#               (query1): Linear(in_features=1024, out_features=1024, bias=True)
#               (key1): Linear(in_features=1024, out_features=1024, bias=True)
#               (value1): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (query2): Linear(in_features=768, out_features=1024, bias=True)
#               (key2): Linear(in_features=768, out_features=1024, bias=True)
#               (value2): Linear(in_features=768, out_features=1024, bias=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (biOutput): BertBiOutput(
#               (dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm1): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (q_dense1): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_dropout1): Dropout(p=0.1, inplace=False)
#               (dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (LayerNorm2): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout2): Dropout(p=0.1, inplace=False)
#               (q_dense2): Linear(in_features=1024, out_features=768, bias=True)
#               (q_dropout2): Dropout(p=0.1, inplace=False)
#             )
#             (v_intermediate): BertImageIntermediate(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (v_output): BertImageOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (t_intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (t_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (t_pooler): BertTextPooler(
#         (dense): Linear(in_features=768, out_features=1024, bias=True)
#         (activation): ReLU()
#       )
#       (v_pooler): BertImagePooler(
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (activation): ReLU()
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#     (classifier): Sequential(
#       (0): BertPredictionHeadTransform(
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       )
#       (1): Linear(in_features=1024, out_features=2, bias=True)
#     )
#   )
#   (losses): Losses(
#     (losses): ModuleList(
#       (0): MMFLoss(
#         (loss_criterion): CrossEntropyLoss(
#           (loss_fn): CrossEntropyLoss()
#         )
#       )
#     )
#   )
# )
# 2020-11-08T10:27:45 | mmf.utils.general: Total Parameters: 247780354. Trained Parameters: 247780354
# 2020-11-08T10:27:45 | mmf.trainers.core.training_loop: Starting training...
# WARNING 2020-11-08T10:28:30 | py.warnings: /usr/local/lib/python3.6/dist-packages/transformers/optimization.py:146: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   exp_avg.mul_(beta1).add_(1.0 - beta1, grad)
#
# WARNING 2020-11-08T10:28:30 | py.warnings: /usr/local/lib/python3.6/dist-packages/transformers/optimization.py:146: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   exp_avg.mul_(beta1).add_(1.0 - beta1, grad)
#
# Process Process-3:
# Process Process-2:
# Process Process-1:
# Process Process-4:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/usr/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/usr/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/usr/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# ^C

# %%
#run best vilbert model
# !mmf_predict config=save/config.yaml model=vilbert dataset=hateful_memes run_type=test checkpoint.resume=True training.batch_size=16 dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# 2020-10-31 16:01:30.449001: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option config to save/config.yaml
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option model to vilbert
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option run_type to test
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option checkpoint.resume to True
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option training.batch_size to 16
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.val[0] to hateful_memes/defaults/annotations/dev_seen.jsonl
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option dataset_config.hateful_memes.annotations.test[0] to hateful_memes/defaults/annotations/test_seen.jsonl
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option env.report_dir to /content/drive/My Drive/msc computer science/deep learning/DL course
# 2020-10-31T16:01:37 | mmf.utils.configuration: Overriding option evaluation.predict to true
# 2020-10-31T16:01:37 | mmf: Logging to: ./save/train.log
# 2020-10-31T16:01:37 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=save/config.yaml', 'model=vilbert', 'dataset=hateful_memes', 'run_type=test', 'checkpoint.resume=True', 'training.batch_size=16', 'dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl', 'dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl', 'env.report_dir=/content/drive/My Drive/msc computer science/deep learning/DL course', 'evaluation.predict=true'])
# 2020-10-31T16:01:37 | mmf_cli.run: Torch version: 1.6.0+cu101
# 2020-10-31T16:01:37 | mmf.utils.general: CUDA Device 0 is: Tesla P100-PCIE-16GB
# 2020-10-31T16:01:37 | mmf_cli.run: Using seed 30890431
# 2020-10-31T16:01:37 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-10-31T16:01:38 | transformers.tokenization_utils: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2020-10-31T16:01:40 | mmf.trainers.mmf_trainer: Loading model
# 2020-10-31T16:01:40 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-10-31T16:01:56 | transformers.modeling_utils: Weights of ViLBERTBase not initialized from pretrained model: ['bert.v_embeddings.image_embeddings.weight', 'bert.v_embeddings.image_embeddings.bias', 'bert.v_embeddings.image_location_embeddings.weight', 'bert.v_embeddings.image_location_embeddings.bias', 'bert.v_embeddings.LayerNorm.weight', 'bert.v_embeddings.LayerNorm.bias', 'bert.encoder.v_layer.0.attention.self.query.weight', 'bert.encoder.v_layer.0.attention.self.query.bias', 'bert.encoder.v_layer.0.attention.self.key.weight', 'bert.encoder.v_layer.0.attention.self.key.bias', 'bert.encoder.v_layer.0.attention.self.value.weight', 'bert.encoder.v_layer.0.attention.self.value.bias', 'bert.encoder.v_layer.0.attention.output.dense.weight', 'bert.encoder.v_layer.0.attention.output.dense.bias', 'bert.encoder.v_layer.0.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.0.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.0.intermediate.dense.weight', 'bert.encoder.v_layer.0.intermediate.dense.bias', 'bert.encoder.v_layer.0.output.dense.weight', 'bert.encoder.v_layer.0.output.dense.bias', 'bert.encoder.v_layer.0.output.LayerNorm.weight', 'bert.encoder.v_layer.0.output.LayerNorm.bias', 'bert.encoder.v_layer.1.attention.self.query.weight', 'bert.encoder.v_layer.1.attention.self.query.bias', 'bert.encoder.v_layer.1.attention.self.key.weight', 'bert.encoder.v_layer.1.attention.self.key.bias', 'bert.encoder.v_layer.1.attention.self.value.weight', 'bert.encoder.v_layer.1.attention.self.value.bias', 'bert.encoder.v_layer.1.attention.output.dense.weight', 'bert.encoder.v_layer.1.attention.output.dense.bias', 'bert.encoder.v_layer.1.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.1.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.1.intermediate.dense.weight', 'bert.encoder.v_layer.1.intermediate.dense.bias', 'bert.encoder.v_layer.1.output.dense.weight', 'bert.encoder.v_layer.1.output.dense.bias', 'bert.encoder.v_layer.1.output.LayerNorm.weight', 'bert.encoder.v_layer.1.output.LayerNorm.bias', 'bert.encoder.v_layer.2.attention.self.query.weight', 'bert.encoder.v_layer.2.attention.self.query.bias', 'bert.encoder.v_layer.2.attention.self.key.weight', 'bert.encoder.v_layer.2.attention.self.key.bias', 'bert.encoder.v_layer.2.attention.self.value.weight', 'bert.encoder.v_layer.2.attention.self.value.bias', 'bert.encoder.v_layer.2.attention.output.dense.weight', 'bert.encoder.v_layer.2.attention.output.dense.bias', 'bert.encoder.v_layer.2.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.2.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.2.intermediate.dense.weight', 'bert.encoder.v_layer.2.intermediate.dense.bias', 'bert.encoder.v_layer.2.output.dense.weight', 'bert.encoder.v_layer.2.output.dense.bias', 'bert.encoder.v_layer.2.output.LayerNorm.weight', 'bert.encoder.v_layer.2.output.LayerNorm.bias', 'bert.encoder.v_layer.3.attention.self.query.weight', 'bert.encoder.v_layer.3.attention.self.query.bias', 'bert.encoder.v_layer.3.attention.self.key.weight', 'bert.encoder.v_layer.3.attention.self.key.bias', 'bert.encoder.v_layer.3.attention.self.value.weight', 'bert.encoder.v_layer.3.attention.self.value.bias', 'bert.encoder.v_layer.3.attention.output.dense.weight', 'bert.encoder.v_layer.3.attention.output.dense.bias', 'bert.encoder.v_layer.3.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.3.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.3.intermediate.dense.weight', 'bert.encoder.v_layer.3.intermediate.dense.bias', 'bert.encoder.v_layer.3.output.dense.weight', 'bert.encoder.v_layer.3.output.dense.bias', 'bert.encoder.v_layer.3.output.LayerNorm.weight', 'bert.encoder.v_layer.3.output.LayerNorm.bias', 'bert.encoder.v_layer.4.attention.self.query.weight', 'bert.encoder.v_layer.4.attention.self.query.bias', 'bert.encoder.v_layer.4.attention.self.key.weight', 'bert.encoder.v_layer.4.attention.self.key.bias', 'bert.encoder.v_layer.4.attention.self.value.weight', 'bert.encoder.v_layer.4.atte ...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 996, in emit
#     stream.write(msg)
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 42, in load
#     super().load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/base_trainer.py", line 30, in load
#     self.load_model()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 91, in load_model
#     self.model = build_model(attributes)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/build.py", line 79, in build_model
#     model.build()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/vilbert.py", line 1353, in build
#     self.model = ViLBERTForClassification(self.config)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/vilbert.py", line 1246, in __init__
#     cache_dir=os.path.join(get_mmf_cache_dir(), "distributed_{}".format(-1)),
#   File "/usr/local/lib/python3.6/dist-packages/transformers/modeling_utils.py", line 480, in from_pretrained
#     model.__class__.__name__, missing_keys))
# Message: "Weights of ViLBERTBase not initialized from pretrained model: ['bert.v_embeddings.image_embeddings.weight', 'bert.v_embeddings.image_embeddings.bias', 'bert.v_embeddings.image_location_embeddings.weight', 'bert.v_embeddings.image_location_embeddings.bias', 'bert.v_embeddings.LayerNorm.weight', 'bert.v_embeddings.LayerNorm.bias', 'bert.encoder.v_layer.0.attention.self.query.weight', 'bert.encoder.v_layer.0.attention.self.query.bias', 'bert.encoder.v_layer.0.attention.self.key.weight', 'bert.encoder.v_layer.0.attention.self.key.bias', 'bert.encoder.v_layer.0.attention.self.value.weight', 'bert.encoder.v_layer.0.attention.self.value.bias', 'bert.encoder.v_layer.0.attention.output.dense.weight', 'bert.encoder.v_layer.0.attention.output.dense.bias', 'bert.encoder.v_layer.0.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.0.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.0.intermediate.dense.weight', 'bert.encoder.v_layer.0.intermediate.dense.bias', 'bert.encoder.v_layer.0.output.dense.weight', 'bert.encoder.v_layer.0.output.dense.bias', 'bert.encoder.v_layer.0.output.LayerNorm.weight', 'bert.encoder.v_layer.0.output.LayerNorm.bias', 'bert.encoder.v_layer.1.attention.self.query.weight', 'bert.encoder.v_layer.1.attention.self.query.bias', 'bert.encoder.v_layer.1.attention.self.key.weight', 'bert.encoder.v_layer.1.attention.self.key.bias', 'bert.encoder.v_layer.1.attention.self.value.weight', 'bert.encoder.v_layer.1.attention.self.value.bias', 'bert.encoder.v_layer.1.attention.output.dense.weight', 'bert.encoder.v_layer.1.attention.output.dense.bias', 'bert.encoder.v_layer.1.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.1.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.1.intermediate.dense.weight', 'bert.encoder.v_layer.1.intermediate.dense.bias', 'bert.encoder.v_layer.1.output.dense.weight', 'bert.encoder.v_layer.1.output.dense.bias', 'bert.encoder.v_layer.1.output.LayerNorm.weight', 'bert.encoder.v_layer.1.output.LayerNorm.bias', 'bert.encoder.v_layer.2.attention.self.query.weight', 'bert.encoder.v_layer.2.attention.self.query.bias', 'bert.encoder.v_layer.2.attention.self.key.weight', 'bert.encoder.v_layer.2.attention.self.key.bias', 'bert.encoder.v_layer.2.attention.self.value.weight', 'bert.encoder.v_layer.2.attention.self.value.bias', 'bert.encoder.v_layer.2.attention.output.dense.weight', 'bert.encoder.v_layer.2.attention.output.dense.bias', 'bert.encoder.v_layer.2.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.2.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.2.intermediate.dense.weight', 'bert.encoder.v_layer.2.intermediate.dense.bias', 'bert.encoder.v_layer.2.output.dense.weight', 'bert.encoder.v_layer.2.output.dense.bias', 'bert.encoder.v_layer.2.output.LayerNorm.weight', 'bert.encoder.v_layer.2.output.LayerNorm.bias', 'bert.encoder.v_layer.3.attention.self.query.weight', 'bert.encoder.v_layer.3.attention.self.query.bias', 'bert.encoder.v_layer.3.attention.self.key.weight', 'bert.encoder.v_layer.3.attention.self.key.bias', 'bert.encoder.v_layer.3.attention.self.value.weight', 'bert.encoder.v_layer.3.attention.self.value.bias', 'bert.encoder.v_layer.3.attention.output.dense.weight', 'bert.encoder.v_layer.3.attention.output.dense.bias', 'bert.encoder.v_layer.3.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.3.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.3.intermediate.dense.weight', 'bert.encoder.v_layer.3.intermediate.dense.bias', 'bert.encoder.v_layer.3.output.dense.weight', 'bert.encoder.v_layer.3.output.dense.bias', 'bert.encoder.v_layer.3.output.LayerNorm.weight', 'bert.encoder.v_layer.3.output.LayerNorm.bias', 'bert.encoder.v_layer.4.attention.self.query.weight', 'bert.encoder.v_layer.4.attention.self.query.bias', 'bert.encoder.v_layer.4.attention.self.key.weight', 'bert.encoder.v_layer.4.attention.self.key.bias', 'bert.encoder.v_layer.4.attention.self.value.weight', 'bert.encoder.v_layer.4.attention.self.value.bias', 'bert.encoder.v_l ...
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 996, in emit
#     stream.write(msg)
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 42, in load
#     super().load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/base_trainer.py", line 30, in load
#     self.load_model()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 91, in load_model
#     self.model = build_model(attributes)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/build.py", line 79, in build_model
#     model.build()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/vilbert.py", line 1353, in build
#     self.model = ViLBERTForClassification(self.config)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/vilbert.py", line 1246, in __init__
#     cache_dir=os.path.join(get_mmf_cache_dir(), "distributed_{}".format(-1)),
#   File "/usr/local/lib/python3.6/dist-packages/transformers/modeling_utils.py", line 480, in from_pretrained
#     model.__class__.__name__, missing_keys))
# Message: "Weights of ViLBERTBase not initialized from pretrained model: ['bert.v_embeddings.image_embeddings.weight', 'bert.v_embeddings.image_embeddings.bias', 'bert.v_embeddings.image_location_embeddings.weight', 'bert.v_embeddings.image_location_embeddings.bias', 'bert.v_embeddings.LayerNorm.weight', 'bert.v_embeddings.LayerNorm.bias', 'bert.encoder.v_layer.0.attention.self.query.weight', 'bert.encoder.v_layer.0.attention.self.query.bias', 'bert.encoder.v_layer.0.attention.self.key.weight', 'bert.encoder.v_layer.0.attention.self.key.bias', 'bert.encoder.v_layer.0.attention.self.value.weight', 'bert.encoder.v_layer.0.attention.self.value.bias', 'bert.encoder.v_layer.0.attention.output.dense.weight', 'bert.encoder.v_layer.0.attention.output.dense.bias', 'bert.encoder.v_layer.0.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.0.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.0.intermediate.dense.weight', 'bert.encoder.v_layer.0.intermediate.dense.bias', 'bert.encoder.v_layer.0.output.dense.weight', 'bert.encoder.v_layer.0.output.dense.bias', 'bert.encoder.v_layer.0.output.LayerNorm.weight', 'bert.encoder.v_layer.0.output.LayerNorm.bias', 'bert.encoder.v_layer.1.attention.self.query.weight', 'bert.encoder.v_layer.1.attention.self.query.bias', 'bert.encoder.v_layer.1.attention.self.key.weight', 'bert.encoder.v_layer.1.attention.self.key.bias', 'bert.encoder.v_layer.1.attention.self.value.weight', 'bert.encoder.v_layer.1.attention.self.value.bias', 'bert.encoder.v_layer.1.attention.output.dense.weight', 'bert.encoder.v_layer.1.attention.output.dense.bias', 'bert.encoder.v_layer.1.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.1.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.1.intermediate.dense.weight', 'bert.encoder.v_layer.1.intermediate.dense.bias', 'bert.encoder.v_layer.1.output.dense.weight', 'bert.encoder.v_layer.1.output.dense.bias', 'bert.encoder.v_layer.1.output.LayerNorm.weight', 'bert.encoder.v_layer.1.output.LayerNorm.bias', 'bert.encoder.v_layer.2.attention.self.query.weight', 'bert.encoder.v_layer.2.attention.self.query.bias', 'bert.encoder.v_layer.2.attention.self.key.weight', 'bert.encoder.v_layer.2.attention.self.key.bias', 'bert.encoder.v_layer.2.attention.self.value.weight', 'bert.encoder.v_layer.2.attention.self.value.bias', 'bert.encoder.v_layer.2.attention.output.dense.weight', 'bert.encoder.v_layer.2.attention.output.dense.bias', 'bert.encoder.v_layer.2.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.2.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.2.intermediate.dense.weight', 'bert.encoder.v_layer.2.intermediate.dense.bias', 'bert.encoder.v_layer.2.output.dense.weight', 'bert.encoder.v_layer.2.output.dense.bias', 'bert.encoder.v_layer.2.output.LayerNorm.weight', 'bert.encoder.v_layer.2.output.LayerNorm.bias', 'bert.encoder.v_layer.3.attention.self.query.weight', 'bert.encoder.v_layer.3.attention.self.query.bias', 'bert.encoder.v_layer.3.attention.self.key.weight', 'bert.encoder.v_layer.3.attention.self.key.bias', 'bert.encoder.v_layer.3.attention.self.value.weight', 'bert.encoder.v_layer.3.attention.self.value.bias', 'bert.encoder.v_layer.3.attention.output.dense.weight', 'bert.encoder.v_layer.3.attention.output.dense.bias', 'bert.encoder.v_layer.3.attention.output.LayerNorm.weight', 'bert.encoder.v_layer.3.attention.output.LayerNorm.bias', 'bert.encoder.v_layer.3.intermediate.dense.weight', 'bert.encoder.v_layer.3.intermediate.dense.bias', 'bert.encoder.v_layer.3.output.dense.weight', 'bert.encoder.v_layer.3.output.dense.bias', 'bert.encoder.v_layer.3.output.LayerNorm.weight', 'bert.encoder.v_layer.3.output.LayerNorm.bias', 'bert.encoder.v_layer.4.attention.self.query.weight', 'bert.encoder.v_layer.4.attention.self.query.bias', 'bert.encoder.v_layer.4.attention.self.key.weight', 'bert.encoder.v_layer.4.attention.self.key.bias', 'bert.encoder.v_layer.4.attention.self.value.weight', 'bert.encoder.v_layer.4.attention.self.value.bias', 'bert.encoder.v_l ...
# Arguments: ()
# 2020-10-31T16:01:56 | transformers.modeling_utils: Weights from pretrained model not used in ViLBERTBase: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 42, in load
#     super().load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/base_trainer.py", line 30, in load
#     self.load_model()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 91, in load_model
#     self.model = build_model(attributes)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/build.py", line 79, in build_model
#     model.build()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/vilbert.py", line 1353, in build
#     self.model = ViLBERTForClassification(self.config)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/vilbert.py", line 1246, in __init__
#     cache_dir=os.path.join(get_mmf_cache_dir(), "distributed_{}".format(-1)),
#   File "/usr/local/lib/python3.6/dist-packages/transformers/modeling_utils.py", line 483, in from_pretrained
#     model.__class__.__name__, unexpected_keys))
# Message: "Weights from pretrained model not used in ViLBERTBase: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']"
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 42, in load
#     super().load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/base_trainer.py", line 30, in load
#     self.load_model()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 91, in load_model
#     self.model = build_model(attributes)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/build.py", line 79, in build_model
#     model.build()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/vilbert.py", line 1353, in build
#     self.model = ViLBERTForClassification(self.config)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/vilbert.py", line 1246, in __init__
#     cache_dir=os.path.join(get_mmf_cache_dir(), "distributed_{}".format(-1)),
#   File "/usr/local/lib/python3.6/dist-packages/transformers/modeling_utils.py", line 483, in from_pretrained
#     model.__class__.__name__, unexpected_keys))
# Message: "Weights from pretrained model not used in ViLBERTBase: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']"
# Arguments: ()
# 2020-10-31T16:02:10 | mmf.trainers.mmf_trainer: Loading optimizer
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 42, in load
#     super().load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/base_trainer.py", line 31, in load
#     self.load_optimizer()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 95, in load_optimizer
#     logger.info("Loading optimizer")
# Message: 'Loading optimizer'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 42, in load
#     super().load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/base_trainer.py", line 31, in load
#     self.load_optimizer()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 95, in load_optimizer
#     logger.info("Loading optimizer")
# Message: 'Loading optimizer'
# Arguments: ()
# 2020-10-31T16:02:10 | mmf.trainers.mmf_trainer: Loading metrics
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 42, in load
#     super().load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/base_trainer.py", line 32, in load
#     self.load_metrics()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 99, in load_metrics
#     logger.info("Loading metrics")
# Message: 'Loading metrics'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 42, in load
#     super().load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/base_trainer.py", line 32, in load
#     self.load_metrics()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 99, in load_metrics
#     logger.info("Loading metrics")
# Message: 'Loading metrics'
# Arguments: ()
# 2020-10-31T16:02:10 | mmf.utils.checkpoint: Loading checkpoint
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 180, in _load
#     logger.info("Loading checkpoint")
# Message: 'Loading checkpoint'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 180, in _load
#     logger.info("Loading checkpoint")
# Message: 'Loading checkpoint'
# Arguments: ()
# WARNING 2020-10-31T16:02:12 | mmf: Key data_parallel is not present in registry, returning default value of None
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 196, in _load
#     state_dict = self.upgrade_state_dict(ckpt["model"])
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 320, in upgrade_state_dict
#     data_parallel = registry.get("data_parallel") or registry.get("distributed")
#   File "/usr/local/lib/python3.6/dist-packages/mmf/common/registry.py", line 439, in get
#     "of {}".format(original_name, default)
# Message: 'Key data_parallel is not present in registry, returning default value of None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 196, in _load
#     state_dict = self.upgrade_state_dict(ckpt["model"])
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 320, in upgrade_state_dict
#     data_parallel = registry.get("data_parallel") or registry.get("distributed")
#   File "/usr/local/lib/python3.6/dist-packages/mmf/common/registry.py", line 439, in get
#     "of {}".format(original_name, default)
# Message: 'Key data_parallel is not present in registry, returning default value of None'
# Arguments: ()
# WARNING 2020-10-31T16:02:12 | mmf: Key distributed is not present in registry, returning default value of None
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 196, in _load
#     state_dict = self.upgrade_state_dict(ckpt["model"])
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 320, in upgrade_state_dict
#     data_parallel = registry.get("data_parallel") or registry.get("distributed")
#   File "/usr/local/lib/python3.6/dist-packages/mmf/common/registry.py", line 439, in get
#     "of {}".format(original_name, default)
# Message: 'Key distributed is not present in registry, returning default value of None'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 196, in _load
#     state_dict = self.upgrade_state_dict(ckpt["model"])
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 320, in upgrade_state_dict
#     data_parallel = registry.get("data_parallel") or registry.get("distributed")
#   File "/usr/local/lib/python3.6/dist-packages/mmf/common/registry.py", line 439, in get
#     "of {}".format(original_name, default)
# Message: 'Key distributed is not present in registry, returning default value of None'
# Arguments: ()
# WARNING 2020-10-31T16:02:12 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:218: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 210, in _load
#     self._load_counts_and_lr_scheduler(ckpt)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 275, in _load_counts_and_lr_scheduler
#     lr_scheduler.load_state_dict(ckpt["lr_scheduler"])
#   File "/usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py", line 218, in load_state_dict
#     warnings.warn(SAVE_STATE_WARNING, UserWarning)
#   File "/usr/lib/python3.6/warnings.py", line 99, in _showwarnmsg
#     msg.file, msg.line)
# Message: '%s'
# Arguments: ('/usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:218: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.\n  warnings.warn(SAVE_STATE_WARNING, UserWarning)\n',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 210, in _load
#     self._load_counts_and_lr_scheduler(ckpt)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 275, in _load_counts_and_lr_scheduler
#     lr_scheduler.load_state_dict(ckpt["lr_scheduler"])
#   File "/usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py", line 218, in load_state_dict
#     warnings.warn(SAVE_STATE_WARNING, UserWarning)
#   File "/usr/lib/python3.6/warnings.py", line 99, in _showwarnmsg
#     msg.file, msg.line)
# Message: '%s'
# Arguments: ('/usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:218: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.\n  warnings.warn(SAVE_STATE_WARNING, UserWarning)\n',)
# WARNING 2020-10-31T16:02:12 | py.warnings: /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:218: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
#
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 210, in _load
#     self._load_counts_and_lr_scheduler(ckpt)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 275, in _load_counts_and_lr_scheduler
#     lr_scheduler.load_state_dict(ckpt["lr_scheduler"])
#   File "/usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py", line 218, in load_state_dict
#     warnings.warn(SAVE_STATE_WARNING, UserWarning)
#   File "/usr/lib/python3.6/warnings.py", line 99, in _showwarnmsg
#     msg.file, msg.line)
# Message: '%s'
# Arguments: ('/usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:218: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.\n  warnings.warn(SAVE_STATE_WARNING, UserWarning)\n',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 210, in _load
#     self._load_counts_and_lr_scheduler(ckpt)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 275, in _load_counts_and_lr_scheduler
#     lr_scheduler.load_state_dict(ckpt["lr_scheduler"])
#   File "/usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py", line 218, in load_state_dict
#     warnings.warn(SAVE_STATE_WARNING, UserWarning)
#   File "/usr/lib/python3.6/warnings.py", line 99, in _showwarnmsg
#     msg.file, msg.line)
# Message: '%s'
# Arguments: ('/usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:218: UserWarning: Please also save or load the state of the optimzer when saving or loading the scheduler.\n  warnings.warn(SAVE_STATE_WARNING, UserWarning)\n',)
# 2020-10-31T16:02:12 | mmf.utils.checkpoint: Checkpoint loaded.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 52, in main
#     trainer.load()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 46, in load
#     self.on_init_start()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/callback_hook.py", line 15, in on_init_start
#     callback.on_init_start(**kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/callbacks/checkpoint.py", line 31, in on_init_start
#     self._checkpoint.load_state_dict()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 166, in load_state_dict
#     self._load(ckpt_filepath)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/utils/checkpoint.py", line 218, in _load
#     logger.info("Checkpoint loaded.")
# Message: 'Checkpoint loaded.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
# ...
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 998, in emit
#     self.flush()
#   File "/usr/lib/python3.6/logging/__init__.py", line 978, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 54, in main
#     trainer.inference()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 138, in inference
#     self.prediction_loop(dataset)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/evaluation_loop.py", line 59, in prediction_loop
#     while reporter.next_dataset():
#   File "/usr/local/lib/python3.6/dist-packages/mmf/common/test_reporter.py", line 69, in next_dataset
#     logger.info(f"Predicting for {self.current_dataset.dataset_name}")
# Message: 'Predicting for hateful_memes'
# Arguments: ()
#   0% 0/63 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 234, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 322, in reduce_storage
#     df = multiprocessing.reduction.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 191, in DupFd
#     return resource_sharer.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 53, in __init__
#     self._id = _resource_sharer.register(send, close)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 77, in register
#     self._start()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 130, in _start
#     self._listener = Listener(authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 432, in __init__
#     address = address or arbitrary_address(family)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 76, in arbitrary_address
#     return tempfile.mktemp(prefix='listener-', dir=util.get_temp_dir())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 114, in get_temp_dir
#     tempdir = tempfile.mkdtemp(prefix='pymp-')
#   File "/usr/lib/python3.6/tempfile.py", line 509, in mkdtemp
#     _os.mkdir(file, 0o700)
# OSError: [Errno 28] No space left on device: '/tmp/pymp-t5vxp2me'
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 234, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 322, in reduce_storage
#     df = multiprocessing.reduction.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 191, in DupFd
#     return resource_sharer.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 53, in __init__
#     self._id = _resource_sharer.register(send, close)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 77, in register
#     self._start()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 130, in _start
#     self._listener = Listener(authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 432, in __init__
#     address = address or arbitrary_address(family)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 76, in arbitrary_address
#     return tempfile.mktemp(prefix='listener-', dir=util.get_temp_dir())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 114, in get_temp_dir
#     tempdir = tempfile.mkdtemp(prefix='pymp-')
#   File "/usr/lib/python3.6/tempfile.py", line 509, in mkdtemp
#     _os.mkdir(file, 0o700)
# OSError: [Errno 28] No space left on device: '/tmp/pymp-68xym5_3'
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 234, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 322, in reduce_storage
#     df = multiprocessing.reduction.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 191, in DupFd
#     return resource_sharer.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 53, in __init__
#     self._id = _resource_sharer.register(send, close)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 77, in register
#     self._start()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 130, in _start
#     self._listener = Listener(authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 432, in __init__
#     address = address or arbitrary_address(family)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 76, in arbitrary_address
#     return tempfile.mktemp(prefix='listener-', dir=util.get_temp_dir())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 114, in get_temp_dir
#     tempdir = tempfile.mkdtemp(prefix='pymp-')
#   File "/usr/lib/python3.6/tempfile.py", line 509, in mkdtemp
#     _os.mkdir(file, 0o700)
# OSError: [Errno 28] No space left on device: '/tmp/pymp-5hlhd133'
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 234, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 322, in reduce_storage
#     df = multiprocessing.reduction.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 191, in DupFd
#     return resource_sharer.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 53, in __init__
#     self._id = _resource_sharer.register(send, close)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 77, in register
#     self._start()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 130, in _start
#     self._listener = Listener(authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 432, in __init__
#     address = address or arbitrary_address(family)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 76, in arbitrary_address
#     return tempfile.mktemp(prefix='listener-', dir=util.get_temp_dir())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 114, in get_temp_dir
#     tempdir = tempfile.mkdtemp(prefix='pymp-')
#   File "/usr/lib/python3.6/tempfile.py", line 509, in mkdtemp
#     _os.mkdir(file, 0o700)
# OSError: [Errno 28] No space left on device: '/tmp/pymp-hlonhnza'
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 234, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 322, in reduce_storage
#     df = multiprocessing.reduction.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 191, in DupFd
#     return resource_sharer.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 53, in __init__
#     self._id = _resource_sharer.register(send, close)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 77, in register
#     self._start()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 130, in _start
#     self._listener = Listener(authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 432, in __init__
#     address = address or arbitrary_address(family)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 76, in arbitrary_address
#     return tempfile.mktemp(prefix='listener-', dir=util.get_temp_dir())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 114, in get_temp_dir
#     tempdir = tempfile.mkdtemp(prefix='pymp-')
#   File "/usr/lib/python3.6/tempfile.py", line 509, in mkdtemp
#     _os.mkdir(file, 0o700)
# OSError: [Errno 28] No space left on device: '/tmp/pymp-vzl9g2b1'
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 234, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 322, in reduce_storage
#     df = multiprocessing.reduction.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 191, in DupFd
#     return resource_sharer.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 53, in __init__
#     self._id = _resource_sharer.register(send, close)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 77, in register
#     self._start()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 130, in _start
#     self._listener = Listener(authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 432, in __init__
#     address = address or arbitrary_address(family)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 76, in arbitrary_address
#     return tempfile.mktemp(prefix='listener-', dir=util.get_temp_dir())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 114, in get_temp_dir
#     tempdir = tempfile.mkdtemp(prefix='pymp-')
#   File "/usr/lib/python3.6/tempfile.py", line 509, in mkdtemp
#     _os.mkdir(file, 0o700)
# OSError: [Errno 28] No space left on device: '/tmp/pymp-prm2e7ke'
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 234, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 322, in reduce_storage
#     df = multiprocessing.reduction.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 191, in DupFd
#     return resource_sharer.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 53, in __init__
#     self._id = _resource_sharer.register(send, close)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 77, in register
#     self._start()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 130, in _start
#     self._listener = Listener(authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 432, in __init__
#     address = address or arbitrary_address(family)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 76, in arbitrary_address
#     return tempfile.mktemp(prefix='listener-', dir=util.get_temp_dir())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 114, in get_temp_dir
#     tempdir = tempfile.mkdtemp(prefix='pymp-')
#   File "/usr/lib/python3.6/tempfile.py", line 509, in mkdtemp
#     _os.mkdir(file, 0o700)
# OSError: [Errno 28] No space left on device: '/tmp/pymp-3xm73in0'
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 234, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 322, in reduce_storage
#     df = multiprocessing.reduction.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/reduction.py", line 191, in DupFd
#     return resource_sharer.DupFd(fd)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 53, in __init__
#     self._id = _resource_sharer.register(send, close)
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 77, in register
#     self._start()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 130, in _start
#     self._listener = Listener(authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 432, in __init__
#     address = address or arbitrary_address(family)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 76, in arbitrary_address
#     return tempfile.mktemp(prefix='listener-', dir=util.get_temp_dir())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 114, in get_temp_dir
#     tempdir = tempfile.mkdtemp(prefix='pymp-')
#   File "/usr/lib/python3.6/tempfile.py", line 509, in mkdtemp
#     _os.mkdir(file, 0o700)
# OSError: [Errno 28] No space left on device: '/tmp/pymp-v8t1tpro'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1171, in __iter__
#     for obj in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 363, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 974, in _next_data
#     idx, data = self._get_data()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 941, in _get_data
#     success, data = self._try_get_data()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 779, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/mmf_predict", line 8, in <module>
#     sys.exit(predict())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/predict.py", line 15, in predict
#     run(predict=True)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 54, in main
#     trainer.inference()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 138, in inference
#     self.prediction_loop(dataset)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/evaluation_loop.py", line 62, in prediction_loop
#     for batch in tqdm.tqdm(dataloader):
#   File "/usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1224, in __iter__
#     self.close()
#   File "/usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1341, in close
#     self.display(pos=0)
#   File "/usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1520, in display
#     self.sp(self.__repr__() if msg is None else msg)
#   File "/usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1131, in __repr__
#     return self.format_meter(**self.format_dict)
#   File "/usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1488, in format_dict
#     prefix=self.desc, ascii=self.ascii, unit=self.unit,
# KeyboardInterrupt

# %%
#fine tune by myslef - vilbert

# !mmf_run config=projects/hateful_memes/configs/vilbert/from_cc.yaml run_type=train_val dataset=hateful_memes model=vilbert dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl \
dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"
# Out:
# Process Process-2:
# Process Process-1:
# Process Process-4:
# Process Process-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/usr/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/usr/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/usr/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/usr/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-27acb5acfbc1> in <module>()
# ----> 1 get_ipython().system('mmf_run config=projects/hateful_memes/configs/vilbert/from_cc.yaml run_type=train_val dataset=hateful_memes model=vilbert dataset_config.hateful_memes.annotations.val[0]=hateful_memes/defaults/annotations/dev_seen.jsonl dataset_config.hateful_memes.annotations.test[0]=hateful_memes/defaults/annotations/test_seen.jsonl env.report_dir="/content/drive/My Drive/msc computer science/deep learning/DL course"')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     438   # stack.
#     439   result = _run_command(
# --> 440       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     441   shell.user_ns['_exit_code'] = result.returncode
#     442   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     193       os.close(child_pty)
#     194
# --> 195       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     196   finally:
#     197     epoll.close()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     220   while True:
#     221     try:
# --> 222       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     223       if result is not None:
#     224         return result
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     322     # TODO(b/115527726): Rather than sleep, poll for incoming messages from
#     323     # the frontend in the same poll as for the output.
# --> 324     time.sleep(0.1)
#     325
#     326
#
# KeyboardInterrupt:

# %% [markdown]
# # LXMert - fine tuning

# %%
# !mmf_run config="/content/drive/My Drive/msc computer science/deep learning/DL course/hatefule_memes_lxmert_default.yaml" run_type=train_val dataset=hateful_memes model=lxmert
# Out:
# 2020-11-08 17:44:14.559828: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/omegaconf/dictconfig.py:252: UserWarning: Keys with dot (model.bert) are deprecated and will have different semantic meaning the next major version of OmegaConf (2.1)
# See the compact keys issue for more details: https://github.com/omry/omegaconf/issues/152
# You can disable this warning by setting the environment variable OC_DISABLE_DOT_ACCESS_WARNING=1
#   warnings.warn(message=msg, category=UserWarning)
# /usr/local/lib/python3.6/dist-packages/mmf/utils/configuration.py:537: UserWarning: Device specified is 'cuda' but cuda is not present. Switching to CPU version.
#   + "Switching to CPU version."
# 2020-11-08T17:44:17 | mmf.utils.configuration: Overriding option config to /content/drive/My Drive/msc computer science/deep learning/DL course/hatefule_memes_lxmert_default.yaml
# 2020-11-08T17:44:17 | mmf.utils.configuration: Overriding option run_type to train_val
# 2020-11-08T17:44:17 | mmf.utils.configuration: Overriding option datasets to hateful_memes
# 2020-11-08T17:44:17 | mmf.utils.configuration: Overriding option model to lxmert
# 2020-11-08T17:44:17 | mmf: Logging to: ./save/train.log
# 2020-11-08T17:44:17 | mmf_cli.run: Namespace(config_override=None, local_rank=None, opts=['config=/content/drive/My Drive/msc computer science/deep learning/DL course/hatefule_memes_lxmert_default.yaml', 'run_type=train_val', 'dataset=hateful_memes', 'model=lxmert'])
# 2020-11-08T17:44:17 | mmf_cli.run: Torch version: 1.6.0
# 2020-11-08T17:44:17 | mmf_cli.run: Using seed 17958810
# 2020-11-08T17:44:17 | mmf.trainers.mmf_trainer: Loading datasets
# 2020-11-08T17:44:19 | torchtext.vocab: Loading vectors from /root/.cache/torch/mmf/glove.6B.300d.txt.pt
# 2020-11-08T17:44:20 | torchtext.vocab: Loading vectors from /root/.cache/torch/mmf/glove.6B.300d.txt.pt
# 2020-11-08T17:44:24 | mmf.trainers.mmf_trainer: Loading model
# 2020-11-08T17:44:25 | transformers.modeling_utils: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/mmf/distributed_-1/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2020-11-08T17:44:30 | transformers.modeling_utils: Weights of LXMERTBase not initialized from pretrained model: ['bert.encoder.visn_fc.visn_fc.weight', 'bert.encoder.visn_fc.visn_fc.bias', 'bert.encoder.visn_fc.visn_layer_norm.weight', 'bert.encoder.visn_fc.visn_layer_norm.bias', 'bert.encoder.visn_fc.box_fc.weight', 'bert.encoder.visn_fc.box_fc.bias', 'bert.encoder.visn_fc.box_layer_norm.weight', 'bert.encoder.visn_fc.box_layer_norm.bias', 'bert.encoder.x_layers.0.visual_attention.att.query.weight', 'bert.encoder.x_layers.0.visual_attention.att.query.bias', 'bert.encoder.x_layers.0.visual_attention.att.key.weight', 'bert.encoder.x_layers.0.visual_attention.att.key.bias', 'bert.encoder.x_layers.0.visual_attention.att.value.weight', 'bert.encoder.x_layers.0.visual_attention.att.value.bias', 'bert.encoder.x_layers.0.visual_attention.output.dense.weight', 'bert.encoder.x_layers.0.visual_attention.output.dense.bias', 'bert.encoder.x_layers.0.visual_attention.output.LayerNorm.weight', 'bert.encoder.x_layers.0.visual_attention.output.LayerNorm.bias', 'bert.encoder.x_layers.0.lang_self_att.self.query.weight', 'bert.encoder.x_layers.0.lang_self_att.self.query.bias', 'bert.encoder.x_layers.0.lang_self_att.self.key.weight', 'bert.encoder.x_layers.0.lang_self_att.self.key.bias', 'bert.encoder.x_layers.0.lang_self_att.self.value.weight', 'bert.encoder.x_layers.0.lang_self_att.self.value.bias', 'bert.encoder.x_layers.0.lang_self_att.output.dense.weight', 'bert.encoder.x_layers.0.lang_self_att.output.dense.bias', 'bert.encoder.x_layers.0.lang_self_att.output.LayerNorm.weight', 'bert.encoder.x_layers.0.lang_self_att.output.LayerNorm.bias', 'bert.encoder.x_layers.0.visn_self_att.self.query.weight', 'bert.encoder.x_layers.0.visn_self_att.self.query.bias', 'bert.encoder.x_layers.0.visn_self_att.self.key.weight', 'bert.encoder.x_layers.0.visn_self_att.self.key.bias', 'bert.encoder.x_layers.0.visn_self_att.self.value.weight', 'bert.encoder.x_layers.0.visn_self_att.self.value.bias', 'bert.encoder.x_layers.0.visn_self_att.output.dense.weight', 'bert.encoder.x_layers.0.visn_self_att.output.dense.bias', 'bert.encoder.x_layers.0.visn_self_att.output.LayerNorm.weight', 'bert.encoder.x_layers.0.visn_self_att.output.LayerNorm.bias', 'bert.encoder.x_layers.0.lang_inter.dense.weight', 'bert.encoder.x_layers.0.lang_inter.dense.bias', 'bert.encoder.x_layers.0.lang_output.dense.weight', 'bert.encoder.x_layers.0.lang_output.dense.bias', 'bert.encoder.x_layers.0.lang_output.LayerNorm.weight', 'bert.encoder.x_layers.0.lang_output.LayerNorm.bias', 'bert.encoder.x_layers.0.visn_inter.dense.weight', 'bert.encoder.x_layers.0.visn_inter.dense.bias', 'bert.encoder.x_layers.0.visn_output.dense.weight', 'bert.encoder.x_layers.0.visn_output.dense.bias', 'bert.encoder.x_layers.0.visn_output.LayerNorm.weight', 'bert.encoder.x_layers.0.visn_output.LayerNorm.bias', 'bert.encoder.x_layers.1.visual_attention.att.query.weight', 'bert.encoder.x_layers.1.visual_attention.att.query.bias', 'bert.encoder.x_layers.1.visual_attention.att.key.weight', 'bert.encoder.x_layers.1.visual_attention.att.key.bias', 'bert.encoder.x_layers.1.visual_attention.att.value.weight', 'bert.encoder.x_layers.1.visual_attention.att.value.bias', 'bert.encoder.x_layers.1.visual_attention.output.dense.weight', 'bert.encoder.x_layers.1.visual_attention.output.dense.bias', 'bert.encoder.x_layers.1.visual_attention.output.LayerNorm.weight', 'bert.encoder.x_layers.1.visual_attention.output.LayerNorm.bias', 'bert.encoder.x_layers.1.lang_self_att.self.query.weight', 'bert.encoder.x_layers.1.lang_self_att.self.query.bias', 'bert.encoder.x_layers.1.lang_self_att.self.key.weight', 'bert.encoder.x_layers.1.lang_self_att.self.key.bias', 'bert.encoder.x_layers.1.lang_self_att.self.value.weight', 'bert.encoder.x_layers.1.lang_self_att.self.value.bias', 'bert.encoder.x_layers.1.lang_self_att.output.dense.weight', 'bert.encoder.x_layers.1.lang_self_att.output.dense.bias', 'bert.encoder.x_layers.1.lang_self_att.output.Layer ...
# 2020-11-08T17:44:30 | transformers.modeling_utils: Weights from pretrained model not used in LXMERTBase: ['bert.encoder.layer.9.attention.self.query.weight', 'bert.encoder.layer.9.attention.self.query.bias', 'bert.encoder.layer.9.attention.self.key.weight', 'bert.encoder.layer.9.attention.self.key.bias', 'bert.encoder.layer.9.attention.self.value.weight', 'bert.encoder.layer.9.attention.self.value.bias', 'bert.encoder.layer.9.attention.output.dense.weight', 'bert.encoder.layer.9.attention.output.dense.bias', 'bert.encoder.layer.9.intermediate.dense.weight', 'bert.encoder.layer.9.intermediate.dense.bias', 'bert.encoder.layer.9.output.dense.weight', 'bert.encoder.layer.9.output.dense.bias', 'bert.encoder.layer.10.attention.self.query.weight', 'bert.encoder.layer.10.attention.self.query.bias', 'bert.encoder.layer.10.attention.self.key.weight', 'bert.encoder.layer.10.attention.self.key.bias', 'bert.encoder.layer.10.attention.self.value.weight', 'bert.encoder.layer.10.attention.self.value.bias', 'bert.encoder.layer.10.attention.output.dense.weight', 'bert.encoder.layer.10.attention.output.dense.bias', 'bert.encoder.layer.10.intermediate.dense.weight', 'bert.encoder.layer.10.intermediate.dense.bias', 'bert.encoder.layer.10.output.dense.weight', 'bert.encoder.layer.10.output.dense.bias', 'bert.encoder.layer.11.attention.self.query.weight', 'bert.encoder.layer.11.attention.self.query.bias', 'bert.encoder.layer.11.attention.self.key.weight', 'bert.encoder.layer.11.attention.self.key.bias', 'bert.encoder.layer.11.attention.self.value.weight', 'bert.encoder.layer.11.attention.self.value.bias', 'bert.encoder.layer.11.attention.output.dense.weight', 'bert.encoder.layer.11.attention.output.dense.bias', 'bert.encoder.layer.11.intermediate.dense.weight', 'bert.encoder.layer.11.intermediate.dense.bias', 'bert.encoder.layer.11.output.dense.weight', 'bert.encoder.layer.11.output.dense.bias', 'bert.encoder.layer.9.attention.output.LayerNorm.weight', 'bert.encoder.layer.9.attention.output.LayerNorm.bias', 'bert.encoder.layer.9.output.LayerNorm.weight', 'bert.encoder.layer.9.output.LayerNorm.bias', 'bert.encoder.layer.10.attention.output.LayerNorm.weight', 'bert.encoder.layer.10.attention.output.LayerNorm.bias', 'bert.encoder.layer.10.output.LayerNorm.weight', 'bert.encoder.layer.10.output.LayerNorm.bias', 'bert.encoder.layer.11.attention.output.LayerNorm.weight', 'bert.encoder.layer.11.attention.output.LayerNorm.bias', 'bert.encoder.layer.11.output.LayerNorm.weight', 'bert.encoder.layer.11.output.LayerNorm.bias']
# 2020-11-08T17:44:30 | mmf.trainers.mmf_trainer: Loading optimizer
# 2020-11-08T17:44:30 | mmf.trainers.mmf_trainer: Loading metrics
# 2020-11-08T17:44:30 | mmf.trainers.mmf_trainer: ===== Model =====
# 2020-11-08T17:44:30 | mmf.trainers.mmf_trainer: LXMERT(
#   (model): LXMERTForClassification(
#     (bert): LXMERTBase(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): LXMERTEncoder(
#         (visn_fc): VisualFeatEncoder(
#           (visn_fc): Linear(in_features=2048, out_features=768, bias=True)
#           (visn_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (box_fc): Linear(in_features=4, out_features=768, bias=True)
#           (box_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (x_layers): ModuleList(
#           (0): LXMERTXLayer(
#             (visual_attention): BertCrossattLayer(
#               (att): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (visn_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (lang_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (visn_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (visn_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): LXMERTXLayer(
#             (visual_attention): BertCrossattLayer(
#               (att): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (visn_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (lang_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (visn_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (visn_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): LXMERTXLayer(
#             (visual_attention): BertCrossattLayer(
#               (att): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (visn_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (lang_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (visn_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (visn_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): LXMERTXLayer(
#             (visual_attention): BertCrossattLayer(
#               (att): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (visn_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (lang_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (visn_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (visn_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): LXMERTXLayer(
#             (visual_attention): BertCrossattLayer(
#               (att): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (visn_self_att): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (lang_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (lang_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (visn_inter): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (visn_output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (r_layers): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#     (classifier): BertVisualAnswerHead(
#       (logit_gqa): Sequential(
#         (0): Linear(in_features=768, out_features=1536, bias=True)
#         (1): GeLU()
#         (2): LayerNorm((1536,), eps=1e-12, elementwise_affine=True)
#         (3): Linear(in_features=1536, out_features=1534, bias=True)
#       )
#       (logit_fc): Sequential(
#         (0): Linear(in_features=768, out_features=1536, bias=True)
#         (1): GeLU()
#         (2): LayerNorm((1536,), eps=1e-12, elementwise_affine=True)
#         (3): Linear(in_features=1536, out_features=2, bias=True)
#       )
#     )
#   )
#   (losses): Losses(
#     (losses): ModuleList(
#       (0): MMFLoss(
#         (loss_criterion): CrossEntropyLoss(
#           (loss_fn): CrossEntropyLoss()
#         )
#       )
#     )
#   )
# )
# 2020-11-08T17:44:30 | mmf.utils.general: Total Parameters: 212666112. Trained Parameters: 212666112
# 2020-11-08T17:44:30 | mmf.trainers.core.training_loop: Starting training...
# Traceback (most recent call last):
#   File "/usr/local/bin/mmf_run", line 8, in <module>
#     sys.exit(run())
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 122, in run
#     main(configuration, predict=predict)
#   File "/usr/local/lib/python3.6/dist-packages/mmf_cli/run.py", line 56, in main
#     trainer.train()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/mmf_trainer.py", line 123, in train
#     self.training_loop()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/training_loop.py", line 31, in training_loop
#     self.run_training_epoch()
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/training_loop.py", line 89, in run_training_epoch
#     report = self.run_training_batch(batch, num_batches_for_this_update)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/training_loop.py", line 159, in run_training_batch
#     report = self._forward(batch)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/trainers/core/training_loop.py", line 176, in _forward
#     model_output = self.model(prepared_batch)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/base_model.py", line 166, in __call__
#     model_output = super().__call__(sample_list, *args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 722, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/lxmert.py", line 713, in forward
#     params = self.get_image_and_text_features(sample_list, device)
#   File "/usr/local/lib/python3.6/dist-packages/mmf/models/lxmert.py", line 655, in get_image_and_text_features
#     bert_input_ids = sample_list.input_ids
#   File "/usr/local/lib/python3.6/dist-packages/mmf/common/sample.py", line 166, in __getattr__
#     "Valid choices are {}".format(key, self.fields())
# AttributeError: Key input_ids not found in the SampleList. Valid choices are ['text', 'id', 'image', 'targets', 'dataset_name', 'dataset_type']
